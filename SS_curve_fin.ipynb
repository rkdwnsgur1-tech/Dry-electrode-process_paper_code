# %% [markdown]
# ## 0.5 um

# %% [markdown]
# ## 1.5 um

# %% [markdown]
# ## 0.1 & 0.5 & 1.5 combine graph

# %% [markdown]
# ## 3 um

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
plt.rc('font', family='serif', size=16)  # 글꼴 및 크기 설정
plt.rc('lines', lw=2)
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)
plt.rc('xtick.major', size=5, width=1.5)
plt.rc('ytick.major', size=5, width=1.5)
plt.rc('axes', linewidth=1.5)

### bold figure edge ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(2)
            ax.spines['bottom'].set_linewidth(2)
            ax.spines['left'].set_linewidth(2)
            ax.spines['right'].set_linewidth(2)

# 1번 그래프용 데이터 (한 줄로 나열)
x = [0, 0.006740697, 0.024678749, 0.049747456, 0.087387655, 0.132567036, 0.187885315, 0.25189408, 0.322587833, 0.401247865, 0.485181609, 0.573999109, 0.667886058, 0.765096932, 0.865854564, 0.969471886, 1.075317537, 1.183577212, 1.293136745, 1.403996138, 1.515412612, 1.627571864, 1.739545421, 1.850033425, 1.959964347, 2.070452351, 2.178712026, 2.284743371, 2.39096041, 2.495691896, 2.595781029, 2.696241551, 2.796330684, 2.890477605, 2.984624526, 3.079142836, 3.167904627, 3.256295031, 3.344685434, 3.429176261, 3.51199584, 3.59481542, 3.675035282, 3.752655426, 3.83027557, 3.906410161, 3.979202258, 4.051994355, 4.124229369, 4.192564807, 4.260900245, 4.329235683, 4.393857238, 4.457921711, 4.522171878, 4.583636634, 4.643987224, 4.704337815, 4.763017158, 4.81983956, 4.876661962, 4.932555894, 4.986221496, 5.039887098, 5.093181312, 5.143133031, 5.193270445, 5.243407859, 5.293545272, 5.343496992, 5.393634405, 5.43931516, 5.483138973, 5.526962787, 5.5707866, 5.614610414, 5.658434227, 5.70132957, 5.741996583, 5.782663597, 5.823144916, 5.863811929, 5.902622001, 5.940874991, 5.97912798, 6.017566664, 6.054334101, 6.090544455, 6.126754809, 6.162965164, 6.197689965, 6.232229072, 6.266953874, 6.30056451, 6.333803758, 6.367228701, 6.399539479, 6.431850256, 6.46397534, 6.495171953, 6.526182872]
y = [0.000021662, 0.39554, 0.82597, 1.2469, 1.8354, 2.488, 3.0337, 3.7798, 4.5258, 5.1228, 5.8859, 6.4494, 7.1962, 7.8964, 8.4322, 9.0984, 9.704, 10.201, 10.773, 11.199, 11.728, 12.205, 12.58, 13.05, 13.388, 13.646, 14.109, 14.491, 14.792, 15.192, 15.531, 15.789, 16.09, 16.489, 16.803, 17.038, 17.492, 17.808, 18.049, 18.472, 18.83, 19.116, 19.503, 19.873, 20.173, 20.526, 20.928, 21.262, 21.59, 22.01, 22.361, 22.644, 23.102, 23.479, 23.792, 24.219, 24.613, 24.944, 25.347, 25.762, 26.117, 26.496, 26.928, 27.3, 27.663, 28.157, 28.595, 28.978, 29.303, 29.569, 29.784, 30.275, 30.812, 31.3, 31.739, 32.127, 32.489, 32.908, 33.397, 33.859, 34.293, 34.703, 35.17, 35.629, 36.064, 36.478, 36.941, 37.409, 37.857, 38.294, 38.767, 39.221, 39.655, 40.129, 40.591, 41.035, 41.511, 41.971, 42.416, 42.897, 43.36]

# 2번 그래프용 데이터
#x2 = [0, 0.00124, 0.02981, 0.04845, 0.06087, 0.08199, 0.10807, 0.1354, 0.17019, 0.20497, 0.24099, 0.26708, 0.29565, 0.32919, 0.37019, 0.42112, 0.48199, 0.53789, 0.60248, 0.64845, 0.68447, 0.7118, 0.7354, 0.77391, 0.80497]
#y2 = [0, 1.09501, 4.95974, 7.72947, 9.08213, 10.04831, 11.01449, 11.91626, 13.01127, 14.2351, 15.33011, 16.36071, 17.32689, 18.55072, 20.03221, 21.64251, 23.76812, 25.82931, 28.4058, 30.59581, 32.39936, 33.88084, 35.29791, 38.13205, 39.80738]

# 그래프 그리기
plt.figure(figsize=(8, 6))

# 첫 번째 그래프
plt.plot(x, y, linestyle='-', color='royalblue', linewidth=4, label="FEM Simulation")
plt.scatter(x[-1], y[-1], color='red', zorder=5, label="Simulation End")

# 두 번째 그래프 (x2 값을 8배)
#plt.plot([v * 8 for v in x2], y2, linestyle='--', color='green', linewidth=3, label="Reference (x2 * 8)")

# 축 눈금 설정
plt.tick_params(axis='x', direction='out', length=6, width=2, labelbottom=False)
plt.tick_params(axis='y', direction='out', length=6, width=2, labelleft=False)

# 라벨, 제목 제거
plt.xlabel("")
plt.ylabel("")
plt.title("")

# 격자 제거
plt.grid(False)

# Figure 경계선을 굵게 설정
bold_figure_edge()

# 축 범위 설정 (필요시 수정)
plt.xlim(min(x)-0.1*min(x), max(x) + 0.1*max(x))
plt.ylim(min(y)-0.01, max(y) + 0.1 * max(y))

# 범례 표시
#plt.legend()
plt.savefig("Ideal_SS_curve",dpi=300, transparent=True, bbox_inches='tight')

# 그래프 보여주기
plt.show()

# %% [markdown]
# ## 10 um

# %% [markdown]
# ## 15 um

# %% [markdown]
# ## 20 um

# %% [markdown]
# ## 3 & 10 &20 conbime graph

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# 새로운 데이터
x1_new = [
    0, 0.0035, 0.00865, 0.0144, 0.0206, 0.0272, 0.03405, 0.04115, 0.04855, 
    0.05625, 0.06425, 0.07255, 0.08105, 0.08985, 0.099, 0.10845, 0.1183, 
    0.12865, 0.1394, 0.1506, 0.16245, 0.1749, 0.18805, 0.20195, 0.2166, 0.2319
]
y1_new = [
    0.000017392, 0.74174, 1.0096, 1.1795, 1.3101, 1.4238, 1.52, 1.6028, 
    1.6841, 1.7469, 1.8222, 1.8794, 1.9397, 1.9964, 2.0498, 2.1003, 
    2.1416, 2.187, 2.2386, 2.2804, 2.3138, 2.3667, 2.412, 2.4715, 
    2.5331, 2.5985
]
x2_new = [
    0, 0.0051, 0.01885, 0.03575, 0.05385, 0.0728, 0.09245, 0.113, 0.1343, 
    0.15635, 0.1792, 0.2032, 0.2283, 0.2542, 0.28135, 0.3098, 0.33975, 
    0.3714, 0.40485, 0.4404, 0.4782, 0.51865, 0.562, 0.6086, 0.6586, 
    0.712, 0.7645, 0.8155, 0.8641, 0.9093, 0.9498
]
y2_new = [
    0.000058961, 1.2694, 2.9569, 3.9178, 4.5232, 4.9689, 5.3381, 5.6377, 
    5.9339, 6.1697, 6.4008, 6.5606, 6.7904, 6.9441, 7.1071, 7.2614, 
    7.4068, 7.5525, 7.6965, 7.8512, 8.0215, 8.2185, 8.4699, 8.7933, 
    9.208, 9.7262, 10.041, 10.469, 10.875, 11.331, 11.681
]
x3_new = [
    0, 0.00515, 0.02015, 0.04515, 0.0766, 0.11085, 0.1471, 0.18505, 0.22465, 
    0.2662, 0.30945, 0.35465, 0.4026, 0.45285, 0.5059, 0.5625, 0.623, 
    0.68765, 0.75725, 0.8324, 0.91395, 1.00285, 1.1002, 1.207, 1.32405, 
    1.44995, 1.57655, 1.69875, 1.81515, 1.924, 2.024
]
y3_new = [
    0.00010018, 1.7821, 3.7686, 5.9957, 7.9273, 9.2831, 10.45, 11.398, 
    12.255, 12.914, 13.448, 13.865, 14.208, 14.448, 14.648, 14.835, 
    15.007, 15.15, 15.297, 15.452, 15.678, 16.014, 16.654, 17.717, 
    19.294, 21.338, 23.15, 24.674, 26.034, 27.209, 28.108
]

# 기존 데이터 (3, 10, 20 um)
x1 = [
    0, 0.00625, 0.02405, 0.0541, 0.095, 0.1434, 0.196, 0.25205, 0.3117, 
    0.37525, 0.44205, 0.51295, 0.58915, 0.67105, 0.76, 0.8574, 0.9651, 
    1.0852, 1.2203, 1.37355, 1.54875, 1.74945, 1.97735, 2.2294, 2.49755, 2.7732
]
y1 = [
    0.00013571, 2.4006, 4.9172, 7.6323, 10.437, 13.086, 15.339, 17.364, 18.962, 
    20.351, 21.355, 22.028, 22.389, 22.509, 22.497, 22.427, 22.391, 22.464, 
    22.691, 23.164, 24.035, 25.755, 28.458, 31.673, 34.805, 37.817
]
x2 = [
    0, 0.005775, 0.02185, 0.04865, 0.08595, 0.1321, 0.185375, 0.24395, 0.307,
    0.37395, 0.445275, 0.52085, 0.601575, 0.688675, 0.784075, 0.88835,
    1.004575, 1.13525, 1.283975, 1.454925, 1.65325, 1.88425, 2.153, 2.4595,
    2.79575, 3.14075
]
y2 = [
    0.00010105, 2.13, 4.3328, 6.657, 9.1866, 12.049, 14.904, 17.691, 20.365,
    22.468, 23.876, 25.234, 25.948, 26.219, 26.269, 25.982, 25.532, 25.086,
    24.94, 25.342, 26.42, 28.631, 32.246, 36.871, 40.773, 42.688
]
x3 = [
    0, 0.00626, 0.024, 0.05344, 0.0941, 0.14452, 0.2033, 0.2692, 0.34112,
    0.41866, 0.50234, 0.59332, 0.69318, 0.80448, 0.93062, 1.0762, 1.2476,
    1.4546, 1.7092, 2.027, 2.42, 2.8734, 3.3232, 3.6974, 3.9694, 4.1644
]
y3 = [
    0.0001023, 2.0403, 4.1521, 6.485, 9.2716, 12.762, 16.869, 21.394, 25.887,
    29.331, 31.57, 32.838, 33.401, 33.221, 32.847, 32.846, 33.62, 36.369,
    42.286, 53.727, 72.261, 97.976, 124.85, 141.36, 145.25, 142.11
]

###############################################################################
# 1) Figure, Axes 생성 시 facecolor='white' (투명은 facecolor='none')
###############################################################################
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)

# 모든 선 굵기 통일: linewidth=3
# (1) 기존 데이터 3, 10, 20 um
ax.plot(x1, y1, linestyle='-', color='tab:blue', linewidth=3, label="3 um (old)")
#ax.scatter(x1[-1], y1[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)

ax.plot(x2, y2, linestyle='-', color='tab:orange', linewidth=3, label="10 um (old)")
#ax.scatter(x2[-1], y2[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)

ax.plot(x3, y3, linestyle='-', color='tab:green', linewidth=3, label="20 um (old)")
#ax.scatter(x3[-1], y3[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)

# (2) 새 데이터 0.1, 0.5, 1.5 um
ax.plot(x1_new, y1_new, linestyle='-', color='tab:red', linewidth=3, label="1.5 um (new)")
ax.plot(x2_new, y2_new, linestyle='-', color='tab:purple', linewidth=3, label="0.5 um (new)")
ax.plot(x3_new, y3_new, linestyle='-', color='tab:brown', linewidth=3, label="0.1 um (new)")

#ax.scatter(x1_new[-1], y1_new[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)
#ax.scatter(x2_new[-1], y2_new[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)
#ax.scatter(x3_new[-1], y3_new[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)

# 축 눈금 설정 (크기는 tick_params의 labelsize 인자로 조절)
# labelbottom=True, labelleft=True로 해서 숫자가 보이게 설정
ax.tick_params(
    axis='x', direction='out', length=6, width=2, 
    labelbottom=True, labelsize=18  # <-- 여기서 숫자 크기 조절
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2, 
    labelleft=True, labelsize=18    # <-- 여기서 숫자 크기 조절
)

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 축 범위 조정 (필요시 수정)
ax.set_xlim(min(x1) - 0.1*min(x1), max(x2) + max(x2)*0.1)
ax.set_ylim(min(y1) - 0.01, 50)

# 파괴 기준선 (점선)만 표시
threshold = 45
ax.axhline(threshold, color='black', linestyle='--', linewidth=2, zorder=2)

# 20 um에서 threshold 초과 구간 표시 (예시)
exceed_indices = [i for i, val in enumerate(y3) if val >= threshold]
if exceed_indices:
    idx_fail_start = exceed_indices[0]
    x_fail = x3[idx_fail_start]
    y_fail = y3[idx_fail_start]
    ax.annotate(
        "Failure",
        xy=(x_fail, y_fail),
        xytext=(x_fail+0.2, y_fail+5),
        arrowprops=dict(
            arrowstyle="->",
            color='red'
        ),
        fontsize=12,
        color='red'
    )

plt.savefig("particle_size_SS_curve.png", transparent=True)
plt.show()

# %% [markdown]
# ## Unimodal

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# 새로운 데이터
x1_new = [0, 0.0027, 0.0069, 0.0115, 0.0165, 0.02175, 0.02725, 0.03295, 0.03885, 0.0449, 0.05115, 0.05755, 0.06415, 0.07095, 0.0779, 0.085, 0.09235, 0.09985, 0.1076, 0.11555, 0.1237, 0.1321, 0.14075, 0.14975, 0.1591, 0.1688]
y1_new = [0.000012561, 0.58325, 0.82034, 0.95409, 1.0598, 1.1507, 1.2302, 1.3242, 1.3802, 1.4243, 1.4786, 1.532, 1.5958, 1.6295, 1.6726, 1.7117, 1.7558, 1.7994, 1.826, 1.8618, 1.9033, 1.9318, 1.9664, 1.9986, 2.0301, 2.0743]

x3_new = [0, 0.00435, 0.01665, 0.0375, 0.06675, 0.10285, 0.1438, 0.18775, 0.23405, 0.28255, 0.33315, 0.3865, 0.44215, 0.5005, 0.56185, 0.62675, 0.69565, 0.7693, 0.8486, 0.9342, 1.02725, 1.12885, 1.2405, 1.36365, 1.50005, 1.65155]
y3_new = [0.000098012, 1.7185, 3.516, 5.4219, 7.4691, 9.5226, 11.475, 13.089, 14.567, 15.785, 16.932, 17.865, 18.504, 18.961, 19.275, 19.459, 19.535, 19.512, 19.484, 19.452, 19.483, 19.596, 19.78, 20.155, 20.685, 21.605]

# 기존 데이터 (3, 10, 20 um)
x2 = [0, 0.0052, 0.019775, 0.044075, 0.07805, 0.1204, 0.169625, 0.224075, 0.28265, 0.345, 0.4109, 0.48055, 0.554425, 0.63335, 0.7181, 0.809925, 0.91035, 1.02175, 1.145925, 1.28605, 1.445675, 1.62925, 1.8415, 2.08725, 2.37, 2.6865]
y2 = [0.00009383, 1.943, 3.9966, 6.1237, 8.4971, 11.126, 13.833, 16.691, 19.289, 21.317, 22.855, 24.171, 25.017, 25.489, 25.68, 25.619, 25.258, 24.93, 24.575, 24.502, 24.871, 25.938, 28.018, 31.303, 35.865, 40.509]

x3 = [0, 0.005925, 0.022675, 0.050375, 0.088425, 0.13565, 0.190975, 0.253475, 0.32225, 0.397025, 0.4782, 0.567075, 0.665675, 0.77645, 0.903425, 1.05265, 1.2327, 1.456175, 1.7405, 2.102, 2.52775, 2.938, 3.2485, 3.46425, 3.62925, 3.7715]
y3 = [0.000088583, 1.7211, 3.4664, 5.5504, 8.2513, 11.738, 16.134, 21.026, 26.133, 30.286, 33.196, 35.088, 36.185, 36.728, 36.74, 37.001, 38.79, 45.906, 60.244, 87.74, 127.8, 166.44, 183.88, 179.95, 166.84, 150.92]


###############################################################################
# 1) Figure, Axes 생성 시 facecolor='white' (투명은 facecolor='none')
###############################################################################
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)

# 모든 선 굵기 통일: linewidth=3
# (1) 기존 데이터 3, 10, 20 um

ax.plot(x2, y2, linestyle='-', color='tab:orange', linewidth=3, label="10 um (old)")
ax.plot(x3, y3, linestyle='-', color='tab:green', linewidth=3, label="20 um (old)")

# (2) 새 데이터 0.1, 0.5, 1.5 um
ax.plot(x1_new, y1_new, linestyle='-', color='tab:red', linewidth=3, label="1.5 um (new)")
ax.plot(x3_new, y3_new, linestyle='-', color='tab:brown', linewidth=3, label="0.1 um (new)")

# 축 눈금 설정 (크기는 tick_params의 labelsize 인자로 조절)
ax.tick_params(
    axis='x', direction='out', length=6, width=2, 
    labelbottom=True, labelsize=18  # <-- 여기서 숫자 크기 조절
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2, 
    labelleft=True, labelsize=18    # <-- 여기서 숫자 크기 조절
)

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 축 범위 조정 (필요시 수정)
ax.set_xlim(min(x1_new) - 0.1*min(x1_new), max(x2) + max(x2)*0.1)
ax.set_ylim(min(y1_new) - 0.01, 50)

# 파괴 기준선 (점선)만 표시
threshold = 45
ax.axhline(threshold, color='black', linestyle='--', linewidth=2, zorder=2)



plt.savefig("particle_size_SS_curve_paper.png", transparent=True)
plt.show()

# %% [markdown]
# ## Bimodal

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=23)
rc('ytick', labelsize=23)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')


def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# 기존 데이터 (10 10, 10 5, 10 1.5 um)
x1 = [0, 0.0052, 0.019775, 0.044075, 0.07805, 0.1204, 0.169625, 0.224075, 0.28265, 0.345, 0.4109, 0.48055, 0.554425, 0.63335, 0.7181, 0.809925, 0.91035, 1.02175, 1.145925, 1.28605, 1.445675, 1.62925, 1.8415, 2.08725, 2.37, 2.6865]
y1 = [0.00009383, 1.943, 3.9966, 6.1237, 8.4971, 11.126, 13.833, 16.691, 19.289, 21.317, 22.855, 24.171, 25.017, 25.489, 25.68, 25.619, 25.258, 24.93, 24.575, 24.502, 24.871, 25.938, 28.018, 31.303, 35.865, 40.509]


x2 = [0, 0.0061, 0.023433333, 0.052816667, 0.09325, 0.141716667, 0.195616667, 0.25305, 0.31385, 0.378366667, 0.446666667, 0.519133333, 0.596516667, 0.679833333, 0.770166667, 0.869333333, 0.979, 1.101166667, 1.239, 1.3955, 1.575333333, 1.783, 2.0225, 2.293833333, 2.588, 2.891666667]
y2 = [0.00011346, 2.3928, 4.903, 7.6008, 10.485, 13.322, 15.774, 18.024, 19.859, 21.448, 22.522, 23.21, 23.608, 23.746, 23.726, 23.619, 23.503, 23.517, 23.754, 24.27, 25.217, 26.82, 29.612, 33.515, 37.639, 40.839]
x3 = [0, 0.003783333, 0.014366667, 0.03215, 0.057233333, 0.088916667, 0.12565, 0.16605, 0.208883333, 0.25355, 0.300116667, 0.348633333, 0.399866667, 0.453083333, 0.5086, 0.566733333, 0.627866667, 0.6925, 0.761166667, 0.8345, 0.913, 0.997833333, 1.089333333, 1.189166667, 1.2975, 1.417166667]
y3 = [0.000070776, 1.4847, 3.0381, 4.6486, 6.4148, 8.2037, 9.9619, 11.648, 12.991, 14.368, 15.479, 16.488, 17.438, 18.036, 18.493, 18.808, 19.001, 19.078, 19.074, 19.021, 18.958, 18.929, 18.932, 19.086, 18.933, 19.532]

# 1) Figure, Axes 생성
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)

# (1) 기존 데이터 10um (old) -> RGB로 지정 (tab:purple)
ax.plot(x2, y2, color='#AC81B4', linewidth=3, label="10 um (old)")
ax.plot(x3, y3, color='#0080FF', linewidth=3, label="20 um (old)")
ax.plot(x1, y1, color='#59a14f', linewidth=3, label="1.5 um (new)")

# 축 눈금 설정
ax.tick_params(
    axis='x', direction='out', length=6, width=2,
    labelbottom=True, labelsize=18
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2,
    labelleft=True, labelsize=18
)

# 라벨/제목/격자/테두리
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")
ax.grid(False)
bold_figure_edge()

# 축 범위 (필요시 조정)
ax.set_xlim(min(x1) - 0.1*min(x1), max(x1) + max(x1)*0.1)
ax.set_ylim(min(y1) - 0.01, 50)

# 파괴 기준선 (점선)
threshold = 45
ax.axhline(threshold, color='black', linestyle='--', linewidth=2, zorder=2)
# ✅ 'σ_T' 레이블 추가 (왼쪽에 위치)
ax.text(min(x1) - 0.05, threshold, r'$\sigma_T$', 
        fontsize=23, color='black', verticalalignment='center', horizontalalignment='right')

plt.savefig("Bimodal_SS_curve_paper.png", transparent=True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# ... (사용자 코드 그대로 위에 둠)

# === 최대 strain 값 출력 및 표시 함수 ===
def mark_max_strain(ax, x, y, name, color):
    x = np.array(x); y = np.array(y)
    idx = np.argmax(x)               # 최대 strain의 인덱스
    x_max, y_at_xmax = x[idx], y[idx]
    print(f"{name}  최대 strain = {x_max:.4f}  (해당 stress = {y_at_xmax:.4f})")
    ax.scatter([x_max], [y_at_xmax], s=80, color=color, edgecolors='k', zorder=5)
    ax.text(x_max, y_at_xmax, f"  {name}\n  ε_max={x_max:.2f}",
            va='bottom', ha='left', fontsize=12, color=color)

# 1) Figure, Axes 생성
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)

# (1) 기존 데이터 10um, 20um, 10–5um(가정)
line10, = ax.plot(x2, y2, color='#AC81B4', linewidth=3, label="10 µm")
line20, = ax.plot(x3, y3, color='#0080FF', linewidth=3, label="20 µm")
line10_5, = ax.plot(x1, y1, color='#59a14f', linewidth=3, label="10–5 µm")  # ← x1,y1을 10–5 µm로 사용

# 축 스타일
ax.tick_params(axis='x', direction='out', length=6, width=2, labelbottom=True, labelsize=18)
ax.tick_params(axis='y', direction='out', length=6, width=2, labelleft=True, labelsize=18)
ax.set_xlabel(""); ax.set_ylabel(""); ax.set_title(""); ax.grid(False)

# 굵은 테두리
bold_figure_edge()

# 축 범위
ax.set_xlim(min(x1) - 0.1*min(x1), max(x1) + max(x1)*0.1)
ax.set_ylim(min(y1) - 0.01, 50)

# 파괴 기준선
threshold = 45
ax.axhline(threshold, color='black', linestyle='--', linewidth=2, zorder=2)
ax.text(min(x1) - 0.05, threshold, r'$\sigma_T$', fontsize=23, color='black',
        va='center', ha='right')

# === 최대 strain 포인트 출력 및 표시 ===
mark_max_strain(ax, x2, y2, "10 µm", '#AC81B4')
mark_max_strain(ax, x1, y1, "10–5 µm", '#59a14f')

ax.legend()
plt.savefig("Bimodal_SS_curve_paper.png", transparent=True)
plt.show()
# Out:
# 10 µm  최대 strain = 2.8917  (해당 stress = 40.8390)
# 10–5 µm  최대 strain = 2.6865  (해당 stress = 40.5090)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# x, y 데이터 생성
x = np.linspace(0, 25, 100)
y = np.linspace(0, 25, 100)
X, Y = np.meshgrid(x, y)

# 양의 봉우리 (위로 솟음)
Z1 = np.exp(-((X - 8)**2 + (Y - 12)**2) / 10)

# 음의 봉우리 (아래로 꺼짐)
Z2 = -np.exp(-((X - 15)**2 + (Y - 10)**2) / 10)

# 조합 및 스케일링
Z = (Z1 + Z2) * 8

# 3D Surface Plot
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap='jet', edgecolor='k')

# 컬러바 및 축
#fig.colorbar(surf)
#ax.set_xlabel('X')
#ax.set_ylabel('Y')
#ax.set_zlabel('Z')

plt.show()

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=23)
rc('ytick', labelsize=23)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# 새로운 데이터
x1 = [0, 0.0027, 0.0069, 0.0115, 0.0165, 0.02175, 0.02725, 0.03295, 0.03885, 0.0449, 0.05115, 0.05755, 0.06415, 0.0709, 0.07785, 0.085, 0.0923, 0.0998, 0.10755, 0.1155, 0.12365, 0.132, 0.14065, 0.1496, 0.15885, 0.1685]
y1 = [0.000010463, 0.58281, 0.81515, 0.9541, 1.058, 1.1476, 1.23, 1.302, 1.3716, 1.4276, 1.4804, 1.5302, 1.5851, 1.6291, 1.6706, 1.711, 1.7528, 1.7955, 1.8391, 1.9236, 1.9023, 1.9422, 1.9826, 2.0001, 2.0534, 2.0705]

x2 = [0, 0.0036, 0.0139, 0.03155, 0.05515, 0.0825, 0.1114, 0.14175, 0.17315, 0.2055, 0.2393, 0.27425, 0.3104, 0.34775, 0.3866, 0.42695, 0.46905, 0.5131, 0.55925, 0.60775, 0.65885, 0.71285, 0.77005, 0.83075, 0.89545, 0.9643]
y2 = [0.000060265, 1.2762, 2.6684, 4.2627, 5.8463, 7.1531, 8.1028, 8.9508, 9.6562, 10.219, 10.852, 11.266, 11.622, 11.928, 12.175, 12.39, 12.59, 12.742, 12.88, 13.016, 13.137, 13.254, 13.377, 13.503, 13.653, 13.804]

#x3 = [0, 0.004533333, 0.017233333, 0.038733333, 0.0689, 0.1063, 0.149, 0.195433333, 0.244066667, 0.295233333, 0.348966667, 0.405466667, 0.464633333, 0.526866667, 0.592533333, 0.662233333, 0.736633333, 0.816633333, 0.903066667, 0.9972, 1.1001, 1.213433333, 1.3389, 1.478566667, 1.634833333, 1.809466667]
#y3 = [0.000084627, 1.7844, 3.6385, 5.5962, 7.6872, 9.8688, 11.942, 13.872, 15.401, 16.777, 18.122, 19.089, 19.74, 20.249, 20.553, 20.701, 20.729, 20.673, 20.581, 20.538, 20.581, 20.744, 21.035, 21.387, 22.207, 23.451]

x4 = [0, 0.00515, 0.01965, 0.0439, 0.07785, 0.12025, 0.169475, 0.223875, 0.2825, 0.34485, 0.410725, 0.480425, 0.554425, 0.63335, 0.718125, 0.809975, 0.91045, 1.02175, 1.145725, 1.285675, 1.445275, 1.62875, 1.84075, 2.0865, 2.36925, 2.6855]
y4 = [0.00009383, 1.9655, 4.0004, 6.1331, 8.4949, 11.093, 13.869, 16.707, 19.239, 21.314, 22.856, 24.154, 24.973, 25.492, 25.673, 25.62, 25.334, 24.95, 24.591, 24.512, 24.938, 25.976, 28.013, 31.239, 35.899, 40.49]

x5 = [0, 0.0054, 0.020614286, 0.046028571, 0.081485714, 0.125642857, 0.177014286, 0.234114286, 0.295757143, 0.361628571, 0.431714286, 0.506, 0.585428571, 0.670714286, 0.763142857, 0.864142857, 0.976142857, 1.101714286, 1.244285714, 1.408, 1.598571429, 1.821857143, 2.085285714, 2.391571429, 2.737428571, 3.103714286]
y5 = [0.000095853, 1.9878, 4.041, 6.2116, 8.6452, 11.418, 14.412, 17.633, 20.532, 22.87, 24.598, 25.99, 26.905, 27.332, 27.438, 27.195, 26.74, 26.235, 26.121, 26.545, 27.701, 30.212, 35.39, 41.92, 50.408, 59.295]

x6 = [0, 0.0061, 0.023433333, 0.052816667, 0.09325, 0.141716667, 0.195616667, 0.25305, 0.31385, 0.378366667, 0.446666667, 0.519133333, 0.596516667, 0.679833333, 0.770166667, 0.869333333, 0.979, 1.101166667, 1.239, 1.3955, 1.575333333, 1.783, 2.0225, 2.293833333, 2.588, 2.891666667]
y6 = [0.00011346, 2.3928, 4.903, 7.6008, 10.485, 13.322, 15.774, 18.024, 19.859, 21.448, 22.522, 23.21, 23.608, 23.746, 23.726, 23.619, 23.503, 23.517, 23.754, 24.27, 25.217, 26.82, 29.612, 33.515, 37.639, 40.839]

###############################################################################
# 1) Figure, Axes 생성 시 facecolor='white' (투명은 facecolor='none')
###############################################################################
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)

# 모든 선 굵기 통일: linewidth=3
# (1) 기존 데이터 3, 10, 20 um

ax.plot(x1, y1, linestyle='-', color='#d37295', linewidth=3, label="10 um (old)")
ax.plot(x4, y4, linestyle='-', color='#59a14f', linewidth=3, label="20 um (old)")

# (2) 새 데이터 0.1, 0.5, 1.5 um
#ax.plot(x1, y1, linestyle='-', color='tab:red', linewidth=3, label="1.5 um (new)")
#ax.plot(x3, y3, linestyle='-', color='tab:brown', linewidth=3, label="0.1 um (new)")
ax.plot(x5, y5, linestyle='-', color='#4e79a7', linewidth=3, label="0.1 um (new)")  # 수정: tab:black -> black
ax.plot(x2, y2, linestyle='-', color='#f28e2b', linewidth=3, label="0.1 um (new)")  # 수정: tab:black -> black
# 축 눈금 설정 (크기는 tick_params의 labelsize 인자로 조절)
ax.tick_params(
    axis='x', direction='out', length=6, width=2, 
    labelbottom=True, labelsize=18  # <-- 여기서 숫자 크기 조절
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2, 
    labelleft=True, labelsize=18    # <-- 여기서 숫자 크기 조절
)

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 축 범위 조정 (필요시 수정)
ax.set_xlim(min(x1) - 0.1*min(x1), max(x5) + max(x5)*0.1)
ax.set_ylim(min(y1) - 0.01, 60)

# 파괴 기준선 (점선)만 표시
threshold = 45
ax.axhline(threshold, color='black', linestyle='--', linewidth=2, zorder=2)
# ✅ 'σ_T' 레이블 추가 (왼쪽에 위치)
ax.text(min(x1) - 0.05, threshold, r'$\sigma_T$', 
        fontsize=23, color='black', verticalalignment='center', horizontalalignment='right')


plt.savefig("Figure2_particle_size_SS_curve_paper.png", transparent=True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=23)
rc('ytick', labelsize=23)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

# 굵은 Figure 경계 함수 정의
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# 기존 데이터
x1 = [0, 0.0027, 0.0069, 0.0115, 0.0165, 0.02175, 0.02725, 0.03295, 0.03885, 0.0449, 0.05115, 0.05755, 0.06415, 0.0709, 0.07785, 0.085, 0.0923, 0.0998, 0.10755, 0.1155, 0.12365, 0.132, 0.14065, 0.1496, 0.15885, 0.1685]
y1 = [0.000010463, 0.58281, 0.81515, 0.9541, 1.058, 1.1476, 1.23, 1.302, 1.3716, 1.4276, 1.4804, 1.5302, 1.5851, 1.6291, 1.6706, 1.711, 1.7528, 1.7955, 1.8391, 1.9236, 1.9023, 1.9422, 1.9826, 2.0001, 2.0534, 2.0705]

# 새로운 데이터 (예시로 x5, y5 데이터 사용)
x5 = [0, 0.0054, 0.020614286, 0.046028571, 0.081485714, 0.125642857, 0.177014286, 0.234114286, 0.295757143, 0.361628571, 0.431714286, 0.506, 0.585428571, 0.670714286, 0.763142857, 0.864142857, 0.976142857, 1.101714286, 1.244285714, 1.408, 1.598571429, 1.821857143, 2.085285714, 2.391571429, 2.737428571, 3.103714286]
y5 = [0.000095853, 1.9878, 4.041, 6.2116, 8.6452, 11.418, 14.412, 17.633, 20.532, 22.87, 24.598, 25.99, 26.905, 27.332, 27.438, 27.195, 26.74, 26.235, 26.121, 26.545, 27.701, 30.212, 35.39, 41.92, 50.408, 59.295]

# 목표 y 값 (예시로 y = 25를 찾는다고 가정)
target_y = 30

# target_y에 해당하는 x 값을 찾아서 점으로 표시하고 출력하는 함수
def find_x_for_y(x, y, target_y):
    for i in range(1, len(y)):
        if (y[i-1] <= target_y <= y[i]) or (y[i-1] >= target_y >= y[i]):
            x_interp = x[i-1] + (target_y - y[i-1]) * (x[i] - x[i-1]) / (y[i] - y[i-1])
            return x_interp
    return None

# x5에 대한 target_y = 25에 해당하는 x 값
target_x5 = find_x_for_y(x5, y5, target_y)

# 그래프 그리기
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)

ax.plot(x1, y1, linestyle='-', color='#d37295', linewidth=3, label="10 um (old)")
ax.plot(x5, y5, linestyle='-', color='#4e79a7', linewidth=3, label="0.1 um (new)")

# 해당 y 값에 해당하는 점 표시
if target_x5 is not None:
    ax.plot(target_x5, target_y, 'ko', label=f"y = {target_y}")
    print(f"The x value corresponding to y = {target_y} is: {target_x5}")

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 축 범위 조정
ax.set_xlim(min(x1) - 0.1*min(x1), max(x5) + max(x5)*0.1)
ax.set_ylim(min(y1) - 0.01, 60)

# 굵은 Figure 경계
bold_figure_edge()

# 격자 제거
ax.grid(False)

# 파괴 기준선 (점선)
threshold = 45
ax.axhline(threshold, color='black', linestyle='--', linewidth=2, zorder=2)
ax.text(min(x1) - 0.05, threshold, r'$\sigma_T$', fontsize=23, color='black', verticalalignment='center', horizontalalignment='right')

plt.legend()
plt.show()
# Out:
# The x value corresponding to y = 30 is: 1.8030054618498605

# %% [markdown]
# #Bimodal

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# 새로운 데이터
x1 = [0, 0.0027, 0.0069, 0.0115, 0.0165, 0.02175, 0.02725, 0.03295, 0.03885, 0.0449, 0.05115, 0.05755, 0.06415, 0.0709, 0.07785, 0.085, 0.0923, 0.0998, 0.10755, 0.1155, 0.12365, 0.132, 0.14065, 0.1496, 0.15885, 0.1685]
y1 = [0.000010463, 0.58281, 0.81515, 0.9541, 1.058, 1.1476, 1.23, 1.302, 1.3716, 1.4276, 1.4804, 1.5302, 1.5851, 1.6291, 1.6706, 1.711, 1.7528, 1.7955, 1.8391, 1.9236, 1.9023, 1.9422, 1.9826, 2.0001, 2.0534, 2.0705]

x2 = [0, 0.0036, 0.0139, 0.03155, 0.05515, 0.0825, 0.1114, 0.14175, 0.17315, 0.2055, 0.2393, 0.27425, 0.3104, 0.34775, 0.3866, 0.42695, 0.46905, 0.5131, 0.55925, 0.60775, 0.65885, 0.71285, 0.77005, 0.83075, 0.89545, 0.9643]
y2 = [0.000060265, 1.2762, 2.6684, 4.2627, 5.8463, 7.1531, 8.1028, 8.9508, 9.6562, 10.219, 10.852, 11.266, 11.622, 11.928, 12.175, 12.39, 12.59, 12.742, 12.88, 13.016, 13.137, 13.254, 13.377, 13.503, 13.653, 13.804]

x3 = [0, 0.004533333, 0.017233333, 0.038733333, 0.0689, 0.1063, 0.149, 0.195433333, 0.244066667, 0.295233333, 0.348966667, 0.405466667, 0.464633333, 0.526866667, 0.592533333, 0.662233333, 0.736633333, 0.816633333, 0.903066667, 0.9972, 1.1001, 1.213433333, 1.3389, 1.478566667, 1.634833333, 1.809466667]
y3 = [0.000084627, 1.7844, 3.6385, 5.5962, 7.6872, 9.8688, 11.942, 13.872, 15.401, 16.777, 18.122, 19.089, 19.74, 20.249, 20.553, 20.701, 20.729, 20.673, 20.581, 20.538, 20.581, 20.744, 21.035, 21.387, 22.207, 23.451]

x4 = [0, 0.00515, 0.01965, 0.0439, 0.07785, 0.12025, 0.169475, 0.223875, 0.2825, 0.34485, 0.410725, 0.480425, 0.554425, 0.63335, 0.718125, 0.809975, 0.91045, 1.02175, 1.145725, 1.285675, 1.445275, 1.62875, 1.84075, 2.0865, 2.36925, 2.6855]
y4 = [0.00009383, 1.9655, 4.0004, 6.1331, 8.4949, 11.093, 13.869, 16.707, 19.239, 21.314, 22.856, 24.154, 24.973, 25.492, 25.673, 25.62, 25.334, 24.95, 24.591, 24.512, 24.938, 25.976, 28.013, 31.239, 35.899, 40.49]

x5 = [0, 0.0054, 0.020614286, 0.046028571, 0.081485714, 0.125642857, 0.177014286, 0.234114286, 0.295757143, 0.361628571, 0.431714286, 0.506, 0.585428571, 0.670714286, 0.763142857, 0.864142857, 0.976142857, 1.101714286, 1.244285714, 1.408, 1.598571429, 1.821857143, 2.085285714, 2.391571429, 2.737428571, 3.103714286]
y5 = [0.000095853, 1.9878, 4.041, 6.2116, 8.6452, 11.418, 14.412, 17.633, 20.532, 22.87, 24.598, 25.99, 26.905, 27.332, 27.438, 27.195, 26.74, 26.235, 26.121, 26.545, 27.701, 30.212, 35.39, 41.92, 50.408, 59.295]


###############################################################################
# 1) Figure, Axes 생성 시 facecolor='white' (투명은 facecolor='none')
###############################################################################
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)

# 모든 선 굵기 통일: linewidth=3
# (1) 기존 데이터 3, 10, 20 um

ax.plot(x2, y2, linestyle='-', color='tab:orange', linewidth=3, label="10 um 5 um")
ax.plot(x3, y3, linestyle='-', color='tab:green', linewidth=3, label="10 um 1.5 um")

# (2) 새 데이터 0.1, 0.5, 1.5 um
ax.plot(x1, y1, linestyle='-', color='tab:red', linewidth=3, label="10 um 10 um")
#ax.plot(x3_new, y3_new, linestyle='-', color='tab:brown', linewidth=3, label="0.1 um (new)")

# 축 눈금 설정 (크기는 tick_params의 labelsize 인자로 조절)
ax.tick_params(
    axis='x', direction='out', length=6, width=2, 
    labelbottom=True, labelsize=18  # <-- 여기서 숫자 크기 조절
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2, 
    labelleft=True, labelsize=18    # <-- 여기서 숫자 크기 조절
)

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 축 범위 조정 (필요시 수정)
ax.set_xlim(min(x1) - 0.1*min(x1), max(x1) + max(x1)*0.1)
ax.set_ylim(min(y1) - 0.01, 45)

# 파괴 기준선 (점선)만 표시
threshold = 45
ax.axhline(threshold, color='black', linestyle='--', linewidth=2, zorder=2)

ax.legend()

plt.savefig("particle_size_SS_curve_paper_bimodal.png", transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# ------------------------------------------------------------------------------
# [새 데이터 (예: 0.1 um, 0.5 um, 1.5 um)]
# ------------------------------------------------------------------------------
x1_new = [
    0, 0.0035, 0.00865, 0.0144, 0.0206, 0.0272, 0.03405, 0.04115, 0.04855, 
    0.05625, 0.06425, 0.07255, 0.08105, 0.08985, 0.099, 0.10845, 0.1183, 
    0.12865, 0.1394, 0.1506, 0.16245, 0.1749, 0.18805, 0.20195, 0.2166, 0.2319
]
y1_new = [
    0.000017392, 0.74174, 1.0096, 1.1795, 1.3101, 1.4238, 1.52, 1.6028, 
    1.6841, 1.7469, 1.8222, 1.8794, 1.9397, 1.9964, 2.0498, 2.1003, 
    2.1416, 2.187, 2.2386, 2.2804, 2.3138, 2.3667, 2.412, 2.4715, 
    2.5331, 2.5985
]
x2_new = [
    0, 0.0051, 0.01885, 0.03575, 0.05385, 0.0728, 0.09245, 0.113, 0.1343, 
    0.15635, 0.1792, 0.2032, 0.2283, 0.2542, 0.28135, 0.3098, 0.33975, 
    0.3714, 0.40485, 0.4404, 0.4782, 0.51865, 0.562, 0.6086, 0.6586, 
    0.712, 0.7645, 0.8155, 0.8641, 0.9093, 0.9498
]
y2_new = [
    0.000058961, 1.2694, 2.9569, 3.9178, 4.5232, 4.9689, 5.3381, 5.6377, 
    5.9339, 6.1697, 6.4008, 6.5606, 6.7904, 6.9441, 7.1071, 7.2614, 
    7.4068, 7.5525, 7.6965, 7.8512, 8.0215, 8.2185, 8.4699, 8.7933, 
    9.208, 9.7262, 10.041, 10.469, 10.875, 11.331, 11.681
]


###############################################################################
# 1) Figure, Axes 생성 시 facecolor='white' (투명은 facecolor='none')
###############################################################################
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)


# (2) 새 데이터 0.1, 0.5, 1.5 um
ax.plot(x1_new, y1_new, linestyle='-', color='tab:red', linewidth=3, label="0.1 um")
ax.plot(x2_new, y2_new, linestyle='-', color='tab:purple', linewidth=3, label="0.5 um")


ax.scatter(x1_new[-1], y1_new[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)
ax.scatter(x2_new[-1], y2_new[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)


# 축 눈금 설정 (크기는 tick_params의 labelsize 인자로 조절)
# labelbottom=True, labelleft=True로 해서 숫자가 보이게 설정
ax.tick_params(
    axis='x', direction='out', length=6, width=2, 
    labelbottom=True, labelsize=18  # 숫자 크기
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2, 
    labelleft=True, labelsize=18    # 숫자 크기
)

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 축 범위 조정 (필요시 수정)
ax.set_xlim(min(x2_new) - 0.1*min(x2_new), 1)
ax.set_ylim(min(y1_new) - 0.01, 12)

# 투명 배경으로 저장하고 싶다면 transparent=True 지정
plt.savefig("particle_size_smallsize_SS_curve.png", transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# ------------------------------------------------------------------------------
# [새 데이터 (예: 0.1 um, 0.5 um, 1.5 um)]
# ------------------------------------------------------------------------------
x1_new = [0,0.0054,0.0209,0.0473,0.08215,0.1218,0.1642,0.2088,0.25535,0.3047,0.3562,0.41035,0.4674,0.52785,0.5922,0.66115,0.73535,0.81575,0.90325,0.99895,1.10435,1.22115,1.3515,1.49705,1.6592,1.8373,2.01715,2.1866,2.3436,2.4888,2.6239]
y1_new = [0.00011495,2.0289,4.2128,6.6636,9.0437,10.911,12.509,13.83,14.816,15.84,16.471,17.011,17.321,17.591,17.793,17.929,18.092,18.246,18.444,18.676,18.962,19.379,20.216,21.536,23.702,26.44,28.58,31.448,35.462,39.791,43.542]


###############################################################################
# 1) Figure, Axes 생성 시 facecolor='white' (투명은 facecolor='none')
###############################################################################
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)


# (2) 새 데이터 0.1, 0.5, 1.5 um
ax.plot(x1_new, y1_new, linestyle='-', color='tab:blue', linewidth=3, label="SS curve")



#ax.scatter(x1_new[-1], y1_new[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)



# 축 눈금 설정 (크기는 tick_params의 labelsize 인자로 조절)
# labelbottom=True, labelleft=True로 해서 숫자가 보이게 설정
ax.tick_params(
    axis='x', direction='out', length=6, width=2, 
    labelbottom=True, labelsize=18  # 숫자 크기
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2, 
    labelleft=True, labelsize=18    # 숫자 크기
)

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 축 범위 조정 (필요시 수정)
ax.set_xlim(min(x1_new) - 0.1*min(x1_new), max(x1_new)+max(x1_new)*0.1)
ax.set_ylim(min(y1_new) - 0.01,max(y1_new)+max(y1_new)*0.1)

# 투명 배경으로 저장하고 싶다면 transparent=True 지정
plt.savefig("validation.png", transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# ------------------------------------------------------------------------------
# [새 데이터 (예: 0.1 um, 0.5 um, 1.5 um)]
# ------------------------------------------------------------------------------
x1_new = [0,0.0054,0.0209,0.0473,0.08215,0.1218,0.1642,0.2088,0.25535,0.3047,0.3562,0.41035,0.4674,0.52785,0.5922,0.66115,0.73535,0.81575,0.90325,0.99895,1.10435,1.22115,1.3515,1.49705,1.6592,1.8373,2.01715,2.1866,2.3436,2.4888,2.6239]
y1_new = [0.00011495,2.0289,4.2128,6.6636,9.0437,10.911,12.509,13.83,14.816,15.84,16.471,17.011,17.321,17.591,17.793,17.929,18.092,18.246,18.444,18.676,18.962,19.379,20.216,21.536,23.702,26.44,28.58,31.448,35.462,39.791,43.542]

# 변곡점 x좌표 (예시로 1.10435 사용)
inflection_x = 0.5
inflection_x2 = 1.2
inflection_x3 = 2.6239

###############################################################################
# 1) Figure, Axes 생성 시 facecolor='white' (투명은 facecolor='none')
###############################################################################
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)

# (2) 새 데이터 0.1, 0.5, 1.5 um
ax.plot(x1_new, y1_new, linestyle='-', color='#124A6E', linewidth=3, label="SS curve")

# 변곡점에서의 수직선 추가 (y값 45까지만)
ax.plot([inflection_x, inflection_x], [min(y1_new), 45], color='gray', linestyle='--', linewidth=2)
ax.plot([inflection_x2, inflection_x2], [min(y1_new), 45], color='gray', linestyle='--', linewidth=2)
ax.plot([inflection_x3, inflection_x3], [min(y1_new), 45], color='gray', linestyle='--', linewidth=2)

# y축 45에 점선 추가
ax.axhline(y=45, color='black', linestyle='--', linewidth=2, label='Y=45')

# 축 눈금 설정 (크기는 tick_params의 labelsize 인자로 조절)
ax.tick_params(
    axis='x', direction='out', length=6, width=2, 
    labelbottom=True, labelsize=18  # 숫자 크기
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2, 
    labelleft=True, labelsize=18    # 숫자 크기
)

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 축 범위 조정 (필요시 수정)
ax.set_xlim(min(x1_new) - 0.1*min(x1_new), max(x1_new))
ax.set_ylim(min(y1_new) - 0.01,50)

# 범례 추가
#ax.legend()

# 투명 배경으로 저장하고 싶다면 transparent=True 지정
plt.savefig("validation_with_inflection.png", transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# ------------------------------------------------------------------------------
# [새 데이터 (예: 0.1 um, 0.5 um, 1.5 um)]
# ------------------------------------------------------------------------------
x1_new = [0, 0.0047, 0.0183, 0.04145, 0.0727, 0.10905, 0.1478, 0.18875, 0.2314, 0.2761, 0.3229, 0.3718, 0.42295, 0.47665, 0.5333, 0.5934, 0.65745, 0.72595, 0.79955, 0.879, 0.9653, 1.0591, 1.1618, 1.2749, 1.3998, 1.5377, 1.6814, 1.82505, 1.96445, 2.0964, 2.21915, 2.33325, 2.4396, 2.5387, 2.63135, 2.71815, 2.79905]
y1_new = [0.00016958, 1.7916, 3.7033, 5.8498, 8.0063, 9.8681, 11.29, 12.531, 13.529, 14.491, 15.181, 15.713, 16.072, 16.403, 16.635, 16.807, 16.936, 17.064, 17.211, 17.377, 17.576, 17.794, 18.085, 18.597, 19.429, 20.768, 21.798, 22.846, 24.351, 26.501, 29.006, 31.534, 33.786, 35.548, 36.8, 37.395, 37.491]

# 변곡점 x좌표 (예시로 1.10435 사용)
inflection_x = 0.3
inflection_x2 = 1.2
inflection_x3 = 5

###############################################################################
# 1) Figure, Axes 생성 시 facecolor='white' (투명은 facecolor='none')
###############################################################################
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)

# (2) 새 데이터 0.1, 0.5, 1.5 um
ax.plot(x1_new, y1_new, linestyle='-', color='#124A6E', linewidth=3, label="SS curve")

# 변곡점에서의 수직선 추가 (y값 45까지만)
ax.plot([inflection_x, inflection_x], [min(y1_new), 45], color='gray', linestyle='--', linewidth=2)
ax.plot([inflection_x2, inflection_x2], [min(y1_new), 45], color='gray', linestyle='--', linewidth=2)
ax.plot([inflection_x3, inflection_x3], [min(y1_new), 45], color='gray', linestyle='--', linewidth=2)

# y축 45에 점선 추가
ax.axhline(y=45, color='black', linestyle='--', linewidth=2, label='Y=45')

# ✅ Y축 눈금을 10 간격으로 지정
ax.yaxis.set_major_locator(MultipleLocator(10))

# ✅ X축 눈금 수동 설정 (1.2 표시되도록)
xticks = [0, 0.5, 1.0, 1.2, 1.5, 2.0, 2.5]  # 필요에 따라 조절 가능
ax.set_xticks(xticks)


# 축 눈금 설정 (크기는 tick_params의 labelsize 인자로 조절)
ax.tick_params(
    axis='x', direction='out', length=6, width=2, 
    labelbottom=True, labelsize=18  # 숫자 크기
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2, 
    labelleft=True, labelsize=18    # 숫자 크기
)

# ✅ Y축 눈금을 10 간격으로 지정
ax.yaxis.set_major_locator(MultipleLocator(10))

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 축 범위 조정 (필요시 수정)
ax.set_xlim(min(x1_new) - 0.1*min(x1_new), max(x1_new))
ax.set_ylim(min(y1_new) - 0.01,50)

# 범례 추가
#ax.legend()

# 투명 배경으로 저장하고 싶다면 transparent=True 지정
plt.savefig("validation_with_inflection.png", transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# ------------------------------------------------------------------
x1_new = [0, 0.0047, 0.0183, 0.04145, 0.0727, 0.10905, 0.1478, 0.18875, 0.2314, 0.2761, 
          0.3229, 0.3718, 0.42295, 0.47665, 0.5333, 0.5934, 0.65745, 0.72595, 0.79955, 
          0.879, 0.9653, 1.0591, 1.1618, 1.2749, 1.3998, 1.5377, 1.6814, 1.82505, 1.96445, 
          2.0964, 2.21915, 2.33325, 2.4396, 2.5387, 2.63135, 2.71815, 2.79905]
y1_new = [0.00016958, 1.7916, 3.7033, 5.8498, 8.0063, 9.8681, 11.29, 12.531, 13.529, 14.491, 
          15.181, 15.713, 16.072, 16.403, 16.635, 16.807, 16.936, 17.064, 17.211, 17.377, 
          17.576, 17.794, 18.085, 18.597, 19.429, 20.768, 21.798, 22.846, 24.351, 26.501, 
          29.006, 31.534, 33.786, 35.548, 36.8, 37.395, 37.491]

# 변곡점 x좌표
inflection_x = 0.3
inflection_x2 = 1.2
inflection_x3 = 5

fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)

# Stress-Strain curve
ax.plot(x1_new, y1_new, linestyle='-', color='#124A6E', linewidth=3, label="SS curve")

# 변곡점 수직선
ax.plot([inflection_x, inflection_x], [min(y1_new), 45], color='gray', linestyle='--', linewidth=2)
ax.plot([inflection_x2, inflection_x2], [min(y1_new), 45], color='gray', linestyle='--', linewidth=2)
ax.plot([inflection_x3, inflection_x3], [min(y1_new), 45], color='gray', linestyle='--', linewidth=2)

# y축 45 점선
ax.axhline(y=45, color='black', linestyle='--', linewidth=2)

# ✅ X축 눈금 수동 설정 (1.2 표시되도록)
xticks = [0, 0.5, 1.0, 1.2, 1.5, 2.0, 2.5]  # 필요에 따라 조절 가능
ax.set_xticks(xticks)

# ✅ y축 눈금을 10 간격 + 15.7 추가
yticks = list(range(0, 51, 10)) + [16.5]
ax.set_yticks(sorted(yticks))

# ✅ y=15.7 가로 점선 추가 (x=0 ~ 첫 번째 inflection_x까지만)
ax.hlines(y=18.5, xmin=0, xmax=inflection_x2, colors='gray', linestyles='--', linewidth=2)

# 축 스타일
ax.tick_params(axis='x', direction='out', length=6, width=2, labelsize=18)
ax.tick_params(axis='y', direction='out', length=6, width=2, labelsize=18)

ax.set_xlim(min(x1_new), max(x1_new))
ax.set_ylim(min(y1_new)-0.5, 50)

bold_figure_edge()

plt.savefig("validation_with_inflection.png", transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# ------------------------------------------------------------------
x1_new = [0,
0.00415,
0.016,
0.03625,
0.064,
0.09685,
0.1324,
0.1699,
0.20895,
0.2495,
0.292,
0.3362,
0.38215,
0.4301,
0.4803,
0.53305,
0.58865,
0.64755,
0.71015,
0.777,
0.84855,
0.9255,
1.0084,
1.09825,
1.1959,
1.30255,
1.4134,
1.52585,
1.63865,
1.7499,
1.8578,
1.9608,
2.0578,
2.14825,
2.23295,
2.3122,
2.3862,
2.45535,
2.5198,
2.5802
]
y1_new = [0.00030015,
1.5741,
3.2507,
5.1081,
7.037,
8.7716,
10.115,
11.283,
12.269,
13.062,
13.891,
14.419,
14.848,
15.207,
15.482,
15.689,
15.843,
15.961,
16.12,
16.216,
16.336,
16.499,
16.673,
16.88,
17.127,
17.662,
17.782,
18.133,
18.656,
19.373,
20.367,
21.685,
23.154,
24.526,
25.802,
26.974,
27.92,
28.561,
28.89,
28.996
]

# 변곡점 x좌표
inflection_x = 0.3
inflection_x2 = 1.13
inflection_x3 = 5

fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)

# Stress-Strain curve
ax.plot(x1_new, y1_new, linestyle='-', color='#124A6E', linewidth=3, label="SS curve")

# y=15.7 가로 점선 추가 (x=0 ~ 첫 번째 inflection_x까지만)
ax.hlines(y=16.8, xmin=0, xmax=inflection_x2, colors='gray', linestyles='--', linewidth=2)

# 변곡점 수직선
ax.plot([inflection_x, inflection_x], [min(y1_new), 45], color='gray', linestyle='--', linewidth=2)
ax.plot([inflection_x2, inflection_x2], [min(y1_new), 45], color='gray', linestyle='--', linewidth=2)
ax.plot([inflection_x3, inflection_x3], [min(y1_new), 45], color='gray', linestyle='--', linewidth=2)

# y축 45 점선
ax.axhline(y=45, color='black', linestyle='--', linewidth=2)

# ✅ X축 눈금 수동 설정 (1.2 표시되도록)
xticks = [0, 0.5, 1.13, 1.5, 2.0, 2.5]  # 필요에 따라 조절 가능
ax.set_xticks(xticks)

# ✅ y축 눈금을 10 간격 + 15.7 추가
yticks = list(range(0, 51, 10)) + [16.8]
ax.set_yticks(sorted(yticks))

# ✅ y=15.7 가로 점선 추가 (x=0 ~ 첫 번째 inflection_x까지만)
#ax.hlines(y=16.5, xmin=0, xmax=inflection_x2, colors='gray', linestyles='--', linewidth=2)

# 축 스타일
ax.tick_params(axis='x', direction='out', length=6, width=2, labelsize=18)
ax.tick_params(axis='y', direction='out', length=6, width=2, labelsize=18)

ax.set_xlim(min(x1_new), max(x1_new))
ax.set_ylim(min(y1_new)-0.5, 50)

bold_figure_edge()

plt.savefig("validation_with_inflection.png", transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# ------------------------------------------------------------------
# ✅ 이미지에서 추출한 새 데이터로 x1_new, y1_new 교체
x2_new = [0.072,
0.129,
0.159,
0.182,
0.223,
0.273,
0.342,
0.464,
0.631,
0.799,
0.966,
1.134,
1.301,
1.469,
1.64,
1.804,
1.971,
2.139,
2.306,
2.474,
2.641,
2.809,
2.976,
3.144,
3.311,
3.479,
3.646,
3.802,
3.94,
4.103,
4.271,
4.438,
4.758,
4.925
]
y2_new = [0.436,
2.106,
3.835,
5.547,
8.121,
10.482,
11.899,
13.769,
14.923,
15.887,
16.26,
16.248,
16.754,
16.803,
16.911,
17.444,
17.822,
18.396,
19.129,
19.641,
20.27,
21.094,
22.156,
22.669,
23.517,
24.586,
25.861,
26.683,
27.624,
28.688,
29.554,
30.427,
31.746,
32.484
]

# 기존 x2, y2 데이터 (유지)
x1_new = [0,
0.00415,
0.016,
0.03625,
0.064,
0.09685,
0.1324,
0.1699,
0.20895,
0.2495,
0.292,
0.3362,
0.38215,
0.4301,
0.4803,
0.53305,
0.58865,
0.64755,
0.71015,
0.777,
0.84855,
0.9255,
1.0084,
1.09825,
1.1959,
1.30255
]
y1_new = [0.00030015,
1.5741,
3.2507,
5.1081,
7.037,
8.7716,
10.115,
11.283,
12.269,
13.062,
13.891,
14.419,
14.848,
15.207,
15.482,
15.689,
15.843,
15.961,
16.12,
16.216,
16.336,
16.499,
16.673,
16.88,
17.127,
17.662
]

# 변곡점 x좌표 (기존 값 유지, 필요시 이 값들을 수정하세요)
inflection_x = 0.3
inflection_x2 = 1.13
inflection_x3 = 5

fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)

# Stress-Strain curve (Data 1 - 새 데이터)
ax.plot(x1_new, y1_new, linestyle='-', color='#124A6E', linewidth=3, label="SS curve (Data 1)")

# Data 2 플롯 추가 (기존 데이터)
ax.plot(x2_new, y2_new, linestyle='--', color='red', linewidth=3, label="Data 2")

# 변곡점 수직선
# 참고: x1_new의 x 범위가 0~5 정도로 변경되었으므로, inflection_x3=5는 플롯의 맨 끝에 그려집니다.
ax.plot([inflection_x, inflection_x], [min(y1_new), 45], color='gray', linestyle='--', linewidth=2)
ax.plot([inflection_x2, inflection_x2], [min(y1_new), 45], color='gray', linestyle='--', linewidth=2)
ax.plot([inflection_x3, inflection_x3], [min(y1_new), 45], color='gray', linestyle='--', linewidth=2)

# y축 45 점선
ax.axhline(y=45, color='black', linestyle='--', linewidth=2)

# y=15.7 가로 점선 추가 (x=0 ~ 첫 번째 inflection_x까지만)
ax.hlines(y=16.4, xmin=0, xmax=inflection_x2, colors='gray', linestyles='--', linewidth=2)

# 축 스타일
ax.tick_params(axis='x', direction='out', length=6, width=2, labelsize=18)
ax.tick_params(axis='y', direction='out', length=6, width=2, labelsize=18)

# X축 눈금 (새로운 x1_new 데이터의 범위에 맞춰 x-tick 수동 조절)
xticks = [0, 1.13, 2.0, 3.0, 4.0, 5.0]  # 필요에 따라 조절 가능
ax.set_xticks(xticks)

# y축 눈금을 10 간격 + 15.7 추가
yticks = list(range(0, 51, 10)) + [16.4]
ax.set_yticks(sorted(yticks))

# X, Y 축 범위: 두 데이터를 모두 포함하도록 수정
ax.set_xlim(min(x1_new), max(x1_new))
ax.set_ylim(min(y1_new)-0.5, 40)

# 범례 표시
#ax.legend()

bold_figure_edge()

plt.savefig("validation_with_inflection.png", transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# ------------------------------------------------------------------------------
# [새 데이터 (예: 0.1 um, 0.5 um, 1.5 um)]
# ------------------------------------------------------------------------------
x1_new = [0,0.0054,0.0209,0.0473,0.08215,0.1218,0.1642,0.2088,0.25535,0.3047,0.3562,0.41035,0.4674,0.52785,0.5922,0.66115,0.73535,0.81575,0.90325,0.99895,1.10435,1.22115,1.3515,1.49705,1.6592,1.8373,2.01715,2.1866,2.3436,2.4888,2.6239]
y1_new = [0.00011495,2.0289,4.2128,6.6636,9.0437,10.911,12.509,13.83,14.816,15.84,16.471,17.011,17.321,17.591,17.793,17.929,18.092,18.246,18.444,18.676,18.962,19.379,20.216,21.536,23.702,26.44,28.58,31.448,35.462,39.791,43.542]

# 변곡점 x좌표 (예시로 1.10435 사용)
inflection_x = 0.5
inflection_x2 = 1.13
inflection_x3 = 2.6239



###############################################################################
# 1) Figure, Axes 생성 시 facecolor='white' (투명은 facecolor='none')
###############################################################################
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)

# (2) 새 데이터 0.1, 0.5, 1.5 um
ax.plot(x1_new, y1_new, linestyle='-', color='tab:blue', linewidth=3, label="SS curve")

# y=15.7 가로 점선 추가 (x=0 ~ 첫 번째 inflection_x까지만)
ax.hlines(y=15.9, xmin=0, xmax=inflection_x2, colors='gray', linestyles='--', linewidth=2)

# 변곡점에서의 수직선 추가
ax.axvline(x=inflection_x, color='black', linestyle='--', linewidth=2, label='Inflection Point')
ax.axvline(x=inflection_x2, color='black', linestyle='--', linewidth=2, label='Inflection Point')
ax.axvline(x=inflection_x3, color='black', linestyle='--', linewidth=2, label='Inflection Point')
# 축 눈금 설정 (크기는 tick_params의 labelsize 인자로 조절)
ax.tick_params(
    axis='x', direction='out', length=6, width=2, 
    labelbottom=True, labelsize=18  # 숫자 크기
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2, 
    labelleft=True, labelsize=18    # 숫자 크기
)

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 축 범위 조정 (필요시 수정)
ax.set_xlim(min(x1_new) - 0.1*min(x1_new), max(x1_new)+max(x1_new)*0.1)
ax.set_ylim(min(y1_new) - 0.01,max(y1_new)+max(y1_new)*0.1)

# 범례 추가
#ax.legend()

# 투명 배경으로 저장하고 싶다면 transparent=True 지정
plt.savefig("validation_with_inflection_black.png", transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=26)  # X축 tick 숫자 크기
rc('ytick', labelsize=26)  # Y축 tick 숫자 크기
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)


# 그래프 틀 생성
fig, ax = plt.subplots(figsize=(7, 8))  # 그래프 크기 설정

# X축과 Y축 tick 설정
x_ticks = np.linspace(-2, 4, 4)  # X축 tick 갯수 설정 (0에서 10 사이에 6개)
y_ticks = np.linspace(-4, 6, 11)  # Y축 tick 갯수 설정 (0에서 10 사이에 6개)
ax.set_xticks(x_ticks)           # X축 tick 적용
ax.set_yticks(y_ticks)           # Y축 tick 적용

# 그래프 설정
ax.grid(True, linestyle='--', alpha=0.7)     # 격자선 추가
ax.set_xlim(-3, 5)                           # X축 범위 설정
ax.set_ylim(-4, 6)                           # Y축 범위 설정

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 그래프 출력
plt.tight_layout()  # 레이아웃 조정

# 투명 배경으로 저장하고 싶다면 transparent=True 지정
plt.savefig("graph.png", transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=26)  # X축 tick 숫자 크기
rc('ytick', labelsize=26)  # Y축 tick 숫자 크기
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)


# 그래프 틀 생성
fig, ax = plt.subplots(figsize=(7, 7))  # 그래프 크기 설정

# X축과 Y축 tick 설정
x_ticks = np.linspace(0, 30, 4)  # X축 tick 갯수 설정 (0에서 10 사이에 6개)
y_ticks = np.linspace(-20, 20, 9)  # Y축 tick 갯수 설정 (0에서 10 사이에 6개)
ax.set_xticks(x_ticks)           # X축 tick 적용
ax.set_yticks(y_ticks)           # Y축 tick 적용

# 그래프 설정
ax.grid(True, linestyle='--', alpha=0.7)     # 격자선 추가
ax.set_xlim(-5, 30)                           # X축 범위 설정
ax.set_ylim(-22.5, 21)                           # Y축 범위 설정

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 그래프 출력
plt.tight_layout()  # 레이아웃 조정

# 투명 배경으로 저장하고 싶다면 transparent=True 지정
plt.savefig("graph_2.png", transparent=True)
plt.show()

# %% [markdown]
# ## Low pressure

# %%
import matplotlib.pyplot as plt


# 사용자 정의 rc 설정
plt.rc('font', family='serif', size=16)  # 글꼴 및 크기 설정
plt.rc('lines', lw=2)
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)
plt.rc('xtick.major', size=5, width=1.5)
plt.rc('ytick.major', size=5, width=1.5)
plt.rc('axes', linewidth=1.5)

### bold figure edge ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(2)
            ax.spines['bottom'].set_linewidth(2)
            ax.spines['left'].set_linewidth(2)
            ax.spines['right'].set_linewidth(2)
# 사용자 입력 데이터
x = [0, 0.016619624, 0.061409047, 0.14285449, 0.254400951, 0.399985144, 0.575930328, 0.773527446, 0.987855604, 1.214031048, 1.444477457, 1.667867489, 1.877887544, 2.069338186, 2.237762757, 2.377961821, 2.502005497, 2.612493501, 2.712211246, 2.801715814, 2.88212137, 2.961041373, 3.035690411, 3.100126272, 3.164376439, 3.223427171, 3.280249573, 3.336143504, 3.38590953, 3.435675555, 3.482470475, 3.528336923, 3.571789349, 3.613756221, 3.654423234, 3.693604694, 3.73167199, 3.768439427, 3.804278393, 3.839003194, 3.872799525]
y = [0.000021482, 1.0032, 2.3161, 3.8235, 5.6823, 7.5892, 9.909, 12.287, 14.481, 16.243, 17.39, 18.411, 19.017, 19.295, 19.122, 19.546, 20.016, 20.556, 21.17, 21.845, 22.813, 23.494, 24.225, 25.207, 25.94, 26.981, 27.924, 28.772, 29.787, 30.653, 31.718, 32.684, 33.601, 34.644, 35.644, 36.645, 37.672, 38.698, 39.733, 40.774, 41.816]


# 그래프 그리기
plt.figure(figsize=(8, 6))
plt.plot(x, y, linestyle='-', color='royalblue', linewidth='4', label="FEM Simulation")
plt.scatter(x[-1], y[-1], color='red', zorder=5, label="Simulation End")

# 축 눈금 설정
plt.tick_params(axis='x', direction='out', length=6, width=2, labelbottom=False)
plt.tick_params(axis='y', direction='out', length=6, width=2, labelleft=False)

# 라벨, 제목 제거
plt.xlabel("")
plt.ylabel("")
plt.title("")

# 격자 제거
plt.grid(False)

# Figure 경계선을 굵게 설정
bold_figure_edge()

# 축의 범위를 자동으로 설정 (필요 시 수동 조정 가능)
plt.xlim(min(x)-0.1*min(x), 4)
plt.ylim(min(y)-0.01, max(y) + 0.1 * max(y))

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# ------------------------------------------------------------------------------
# [새 데이터 (예: 0.1 um, 0.5 um, 1.5 um)]
# ------------------------------------------------------------------------------
x = [0, 0.016619624, 0.061409047, 0.14285449, 0.254400951, 0.399985144, 0.575930328, 0.773527446, 0.987855604, 1.214031048, 1.444477457, 1.667867489, 1.877887544, 2.069338186, 2.237762757, 2.377961821, 2.502005497, 2.612493501, 2.712211246, 2.801715814, 2.88212137, 2.961041373, 3.035690411, 3.100126272, 3.164376439, 3.223427171, 3.280249573, 3.336143504, 3.38590953, 3.435675555, 3.482470475, 3.528336923, 3.571789349, 3.613756221, 3.654423234, 3.693604694, 3.73167199, 3.768439427, 3.804278393, 3.839003194, 3.872799525]
y = [0.000021482, 1.0032, 2.3161, 3.8235, 5.6823, 7.5892, 9.909, 12.287, 14.481, 16.243, 17.39, 18.411, 19.017, 19.295, 19.122, 19.546, 20.016, 20.556, 21.17, 21.845, 22.813, 23.494, 24.225, 25.207, 25.94, 26.981, 27.924, 28.772, 29.787, 30.653, 31.718, 32.684, 33.601, 34.644, 35.644, 36.645, 37.672, 38.698, 39.733, 40.774, 41.816]



###############################################################################
# 1) Figure, Axes 생성 시 facecolor='white' (투명은 facecolor='none')
###############################################################################
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)


# (2) 새 데이터 0.1, 0.5, 1.5 um
ax.plot(x, y, linestyle='-', color='tab:blue', linewidth=3, label="SS curve")



ax.scatter(x[-1], y[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)



# 축 눈금 설정 (크기는 tick_params의 labelsize 인자로 조절)
# labelbottom=True, labelleft=True로 해서 숫자가 보이게 설정
ax.tick_params(
    axis='x', direction='out', length=6, width=2, 
    labelbottom=True, labelsize=18  # 숫자 크기
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2, 
    labelleft=True, labelsize=18    # 숫자 크기
)

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 축 범위 조정 (필요시 수정)
ax.set_xlim(min(x1) - 0.1*min(x1), 4)
ax.set_ylim(min(y1) - 0.01, 45)

# 투명 배경으로 저장하고 싶다면 transparent=True 지정
plt.savefig("SS_curve.png", transparent=True)
plt.show()

# %% [markdown]
# ## Fibrillation pressure

# %%
import matplotlib.pyplot as plt


# 사용자 정의 rc 설정
plt.rc('font', family='serif', size=16)  # 글꼴 및 크기 설정
plt.rc('lines', lw=2)
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)
plt.rc('xtick.major', size=5, width=1.5)
plt.rc('ytick.major', size=5, width=1.5)
plt.rc('axes', linewidth=1.5)

### bold figure edge ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(2)
            ax.spines['bottom'].set_linewidth(2)
            ax.spines['left'].set_linewidth(2)
            ax.spines['right'].set_linewidth(2)
# 사용자가 입력한 x, y 값


# 그래프 그리기
plt.figure(figsize=(8, 6))
plt.plot(x, y, linestyle='-', color='royalblue', linewidth='4', label="FEM Simulation")
plt.scatter(x[-1], y[-1], color='red', zorder=5, label="Simulation End")

# 축 눈금 설정
plt.tick_params(axis='x', direction='out', length=6, width=2, labelbottom=False)
plt.tick_params(axis='y', direction='out', length=6, width=2, labelleft=False)

# 라벨, 제목 제거
plt.xlabel("")
plt.ylabel("")
plt.title("")

# 격자 제거
plt.grid(False)

# Figure 경계선을 굵게 설정
bold_figure_edge()

# 축의 범위를 자동으로 설정 (필요 시 수동 조정 가능)
plt.xlim(min(x)-0.1*min(x), 7)
plt.ylim(min(y)-0.01, max(y) + 0.1 * max(y))

# 그래프 보여주기
plt.show()

# %% [markdown]
# ## 현우형, 민성이형 feedback

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
plt.rc('font', family='serif', size=16)  # 글꼴 및 크기 설정
plt.rc('lines', lw=2)
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)
plt.rc('xtick.major', size=5, width=1.5)
plt.rc('ytick.major', size=5, width=1.5)
plt.rc('axes', linewidth=1.5)

### bold figure edge ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(2)
            ax.spines['bottom'].set_linewidth(2)
            ax.spines['left'].set_linewidth(2)
            ax.spines['right'].set_linewidth(2)

# 1번 그래프용 데이터 (한 줄로 나열)
x = [0, 0.016619624, 0.061409047, 0.14285449, 0.254400951, 0.399985144, 0.575930328, 0.773527446, 0.987855604, 1.214031048, 1.444477457, 1.667867489, 1.877887544, 2.069338186, 2.237762757, 2.377961821, 2.502005497, 2.612493501, 2.712211246, 2.801715814, 2.88212137, 2.961041373, 3.035690411, 3.100126272, 3.164376439, 3.223427171, 3.280249573, 3.336143504, 3.38590953, 3.435675555, 3.482470475, 3.528336923, 3.571789349, 3.613756221, 3.654423234, 3.693604694, 3.73167199, 3.768439427, 3.804278393, 3.839003194, 3.872799525]
y = [0.000021482, 1.0032, 2.3161, 3.8235, 5.6823, 7.5892, 9.909, 12.287, 14.481, 16.243, 17.39, 18.411, 19.017, 19.295, 19.122, 19.546, 20.016, 20.556, 21.17, 21.845, 22.813, 23.494, 24.225, 25.207, 25.94, 26.981, 27.924, 28.772, 29.787, 30.653, 31.718, 32.684, 33.601, 34.644, 35.644, 36.645, 37.672, 38.698, 39.733, 40.774, 41.816]

# 2번 그래프용 데이터
x2 = [0, 0.00124, 0.02981, 0.04845, 0.06087, 0.08199, 0.10807, 0.1354, 0.17019, 0.20497, 0.24099, 0.26708, 0.29565, 0.32919, 0.37019, 0.42112, 0.48199, 0.53789, 0.60248, 0.64845, 0.68447, 0.7118, 0.7354, 0.77391, 0.80497]
y2 = [0, 1.09501, 4.95974, 7.72947, 9.08213, 10.04831, 11.01449, 11.91626, 13.01127, 14.2351, 15.33011, 16.36071, 17.32689, 18.55072, 20.03221, 21.64251, 23.76812, 25.82931, 28.4058, 30.59581, 32.39936, 33.88084, 35.29791, 38.13205, 39.80738]

# 그래프 그리기
plt.figure(figsize=(8, 6))

# 첫 번째 그래프
plt.plot(x, y, linestyle='-', color='royalblue', linewidth=4, label="FEM Simulation")
plt.scatter(x[-1], y[-1], color='red', zorder=5, label="Simulation End")

# 두 번째 그래프 (x2 값을 8배)
plt.plot([v for v in x2], y2, linestyle='--', color='green', linewidth=3, label="Reference (x2 * 8)")

# 축 눈금 설정
plt.tick_params(axis='x', direction='out', length=6, width=2, labelbottom=False)
plt.tick_params(axis='y', direction='out', length=6, width=2, labelleft=False)

# 라벨, 제목 제거
plt.xlabel("")
plt.ylabel("")
plt.title("")

# 격자 제거
plt.grid(False)

# Figure 경계선을 굵게 설정
bold_figure_edge()

# 축 범위 설정 (필요시 수정)
plt.xlim(min(x)-0.1*min(x), 4)
plt.ylim(min(y)-0.01, max(y) + 0.1 * max(y))

# 범례 표시
plt.legend()

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# ------------------------------------------------------------------------------
# [새 데이터 (예: 0.1 um, 0.5 um, 1.5 um)]
# ------------------------------------------------------------------------------
x = [5.46E-09,
3.23E-04,
0.0012768,
0.0054916,
0.014038,
0.025008,
0.043267,
0.068314,
0.099254,
0.13866,
0.18786,
0.25326,
0.33052,
0.42351,
0.54837,
0.69088,
0.85816,
1.0791,
1.3271,
1.6142,
1.9891,
2.4065,
2.8753,
3.4316,
4.0429,
4.671,
5.1758,
5.7104
]

y = [0.000084852,
1.8489,
3.6857,
5.6102,
8.2668,
12.907,
18.163,
22.516,
23.525,
24.573,
25.437,
26.851,
28.331,
29.033,
28.95,
29.05,
28.786,
29.12,
29.68,
30.034,
30.521,
31.313,
32.815,
35.117,
37.643,
40.835,
41.976,
43.615
]


###############################################################################
# 1) Figure, Axes 생성 시 facecolor='white' (투명은 facecolor='none')
###############################################################################
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)


# (2) 새 데이터 0.1, 0.5, 1.5 um
ax.plot(x, y, linestyle='-', color='tab:blue', linewidth=3, label="SS curve")



ax.scatter(x[-1], y[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)



# 축 눈금 설정 (크기는 tick_params의 labelsize 인자로 조절)
# labelbottom=True, labelleft=True로 해서 숫자가 보이게 설정
ax.tick_params(
    axis='x', direction='out', length=6, width=2, 
    labelbottom=True, labelsize=18  # 숫자 크기
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2, 
    labelleft=True, labelsize=18    # 숫자 크기
)

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 축 범위 조정 (필요시 수정)
ax.set_xlim(min(x1) - 0.1*min(x1), 6)
ax.set_ylim(min(y1) - 0.01, 45)

# 투명 배경으로 저장하고 싶다면 transparent=True 지정
plt.savefig("SS_curve.png", transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# ------------------------------------------------------------------------------
# [새 데이터 (예: 0.1 um, 0.5 um, 1.5 um)]
# ------------------------------------------------------------------------------
x = [5.60E-09,
3.27E-04,
0.0012649,
0.0053419,
0.013724,
0.023921,
0.041346,
0.06539,
0.094706,
0.13217,
0.17886,
0.24005,
0.31232,
0.39917,
0.51506,
0.64717,
0.8019,
1.0051,
1.2329,
1.4964,
1.8406,
2.2232,
2.6546,
3.1756,
3.7483,
4.3419,
4.8437,
5.3767
]

y = [0.000085824,
1.8684,
3.7141,
5.5733,
8.0854,
12.31,
17.136,
21.168,
21.972,
22.796,
23.537,
24.96,
26.426,
27.241,
27.122,
27.152,
26.947,
27.356,
27.949,
28.341,
28.712,
29.277,
30.433,
32.532,
34.791,
37.891,
39.64,
42.016
]


###############################################################################
# 1) Figure, Axes 생성 시 facecolor='white' (투명은 facecolor='none')
###############################################################################
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)


# (2) 새 데이터 0.1, 0.5, 1.5 um
ax.plot(x, y, linestyle='-', color='tab:blue', linewidth=3, label="SS curve")



ax.scatter(x[-1], y[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)



# 축 눈금 설정 (크기는 tick_params의 labelsize 인자로 조절)
# labelbottom=True, labelleft=True로 해서 숫자가 보이게 설정
ax.tick_params(
    axis='x', direction='out', length=6, width=2, 
    labelbottom=True, labelsize=18  # 숫자 크기
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2, 
    labelleft=True, labelsize=18    # 숫자 크기
)

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 축 범위 조정 (필요시 수정)
ax.set_xlim(min(x) - 0.1, 6)
ax.set_ylim(min(y) - 0.01, 45)

# 투명 배경으로 저장하고 싶다면 transparent=True 지정
plt.savefig("5_4.5.png", transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# ------------------------------------------------------------------------------
# [새 데이터 (예: 0.1 um, 0.5 um, 1.5 um)]
# ------------------------------------------------------------------------------
x = [5.73E-09,
3.25E-04,
0.0012519,
0.0051997,
0.013469,
0.022952,
0.039679,
0.062919,
0.090933,
0.12694,
0.17171,
0.22927,
0.2973,
0.37897,
0.48735,
0.61077,
0.75505,
0.9436,
1.1546,
1.3987,
1.718,
2.0726,
2.4732,
2.963,
3.5015,
4.0642,
4.5622,
5.093
]

y = [0.000086873,
1.8841,
3.7302,
5.5085,
7.9069,
11.729,
16.081,
19.737,
20.387,
21.054,
21.734,
23.087,
24.471,
25.315,
25.118,
25.022,
24.823,
25.209,
25.72,
26.066,
26.251,
26.57,
27.293,
28.676,
30.311,
32.701,
33.708,
35.349
]


###############################################################################
# 1) Figure, Axes 생성 시 facecolor='white' (투명은 facecolor='none')
###############################################################################
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)


# (2) 새 데이터 0.1, 0.5, 1.5 um
ax.plot(x, y, linestyle='-', color='tab:blue', linewidth=3, label="SS curve")



ax.scatter(x[-1], y[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)



# 축 눈금 설정 (크기는 tick_params의 labelsize 인자로 조절)
# labelbottom=True, labelleft=True로 해서 숫자가 보이게 설정
ax.tick_params(
    axis='x', direction='out', length=6, width=2, 
    labelbottom=True, labelsize=18  # 숫자 크기
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2, 
    labelleft=True, labelsize=18    # 숫자 크기
)

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 축 범위 조정 (필요시 수정)
ax.set_xlim(min(x) - 0.1, 6)
ax.set_ylim(min(y) - 0.01, 45)

# 투명 배경으로 저장하고 싶다면 transparent=True 지정
plt.savefig("5_4.png", transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# ------------------------------------------------------------------------------
# [새 데이터 (예: 0.1 um, 0.5 um, 1.5 um)]
# ------------------------------------------------------------------------------
x = [5.46E-09,
3.23E-04,
0.0012768,
0.0054916,
0.014038,
0.025008,
0.043267,
0.068314,
0.099254,
0.13866,
0.18786,
0.25326,
0.33052,
0.42351,
0.54837,
0.69088,
0.85816,
1.0791,
1.3271,
1.6142,
1.9891,
2.4065,
2.8753,
3.4316,
4.0429,
4.671,
5.1758,
5.7104
]

y = [0.000084852,
1.8489,
3.6857,
5.6102,
8.2668,
12.907,
18.163,
22.516,
23.525,
24.573,
25.437,
26.851,
28.331,
29.033,
28.95,
29.05,
28.786,
29.12,
29.68,
30.034,
30.521,
31.313,
32.815,
35.117,
37.643,
40.835,
41.976,
43.615
]


###############################################################################
# 1) Figure, Axes 생성 시 facecolor='white' (투명은 facecolor='none')
###############################################################################
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)


# (2) 새 데이터 0.1, 0.5, 1.5 um
ax.plot(x, y, linestyle='-', color='tab:blue', linewidth=3, label="SS curve")



ax.scatter(x[-1], y[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)



# 축 눈금 설정 (크기는 tick_params의 labelsize 인자로 조절)
# labelbottom=True, labelleft=True로 해서 숫자가 보이게 설정
ax.tick_params(
    axis='x', direction='out', length=6, width=2, 
    labelbottom=True, labelsize=18  # 숫자 크기
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2, 
    labelleft=True, labelsize=18    # 숫자 크기
)

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 축 범위 조정 (필요시 수정)
ax.set_xlim(min(x) - 0.1, 6)
ax.set_ylim(min(y) - 0.01, 45)

# 투명 배경으로 저장하고 싶다면 transparent=True 지정
plt.savefig("5_5.png", transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# ------------------------------------------------------------------------------
# [새 데이터 (예: 0.1 um, 0.5 um, 1.5 um)]
# ------------------------------------------------------------------------------
x = [5.91E-09,
3.22E-04,
0.0012057,
0.0048727,
0.012901,
0.020977,
0.036237,
0.057813,
0.083198,
0.11619,
0.15712,
0.20821,
0.2687,
0.34131,
0.4372,
0.54625,
0.67341,
0.83854,
1.0229,
1.2363,
1.5164,
1.8268,
2.1784,
2.6153,
3.095,
3.6014,
4.0767,
4.5846
]

y = [0.000088286,
1.8905,
3.7198,
5.3518,
7.4713,
10.569,
14.162,
17.261,
17.666,
18.072,
18.641,
19.904,
21.159,
22.088,
21.873,
21.684,
21.551,
22.015,
22.519,
22.939,
22.946,
22.98,
23.332,
24.252,
25.134,
26.774,
26.809,
27.065
]


###############################################################################
# 1) Figure, Axes 생성 시 facecolor='white' (투명은 facecolor='none')
###############################################################################
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)


# (2) 새 데이터 0.1, 0.5, 1.5 um
ax.plot(x, y, linestyle='-', color='tab:blue', linewidth=3, label="SS curve")



ax.scatter(x[-1], y[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)



# 축 눈금 설정 (크기는 tick_params의 labelsize 인자로 조절)
# labelbottom=True, labelleft=True로 해서 숫자가 보이게 설정
ax.tick_params(
    axis='x', direction='out', length=6, width=2, 
    labelbottom=True, labelsize=18  # 숫자 크기
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2, 
    labelleft=True, labelsize=18    # 숫자 크기
)

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 축 범위 조정 (필요시 수정)
ax.set_xlim(min(x) - 0.1, 6)
ax.set_ylim(min(y) - 0.01, 45)

# 투명 배경으로 저장하고 싶다면 transparent=True 지정
plt.savefig("5_3.png", transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# ------------------------------------------------------------------------------
# [새 데이터 (예: 0.1 um, 0.5 um, 1.5 um)]
# ------------------------------------------------------------------------------
x = [5.73E-09,
2.86E-04,
9.98E-04,
0.0039314,
0.011148,
0.016971,
0.030044,
0.049411,
0.070838,
0.099856,
0.13608,
0.1792,
0.23079,
0.29309,
0.37503,
0.4683,
0.57688,
0.7166,
0.8722,
1.0522,
1.2894,
1.5509,
1.8484,
2.2262,
2.6393,
3.0822,
3.5345,
4.0185
]

y = [0.000082648,
1.6834,
3.3004,
4.5538,
6.1721,
8.0943,
10.415,
12.699,
12.864,
12.975,
13.494,
14.404,
15.257,
16.13,
15.958,
15.754,
15.718,
16.096,
16.444,
16.758,
16.516,
16.185,
16.047,
16.309,
16.371,
17.274,
16.537,
15.689
]


###############################################################################
# 1) Figure, Axes 생성 시 facecolor='white' (투명은 facecolor='none')
###############################################################################
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)


# (2) 새 데이터 0.1, 0.5, 1.5 um
ax.plot(x, y, linestyle='-', color='tab:blue', linewidth=3, label="SS curve")



ax.scatter(x[-1], y[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)



# 축 눈금 설정 (크기는 tick_params의 labelsize 인자로 조절)
# labelbottom=True, labelleft=True로 해서 숫자가 보이게 설정
ax.tick_params(
    axis='x', direction='out', length=6, width=2, 
    labelbottom=True, labelsize=18  # 숫자 크기
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2, 
    labelleft=True, labelsize=18    # 숫자 크기
)

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 축 범위 조정 (필요시 수정)
ax.set_xlim(min(x) - 0.1, 6)
ax.set_ylim(min(y) - 0.01, 45)

# 투명 배경으로 저장하고 싶다면 transparent=True 지정
plt.savefig("5_1.png", transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# 데이터 설정
data = [
    {
        "x": [5.46E-09, 3.23E-04, 0.0012768, 0.0054916, 0.014038, 0.025008, 0.043267, 0.068314, 0.099254, 0.13866, 0.18786, 0.25326, 0.33052, 0.42351, 0.54837, 0.69088, 0.85816, 1.0791, 1.3271, 1.6142, 1.9891, 2.4065, 2.8753, 3.4316, 4.0429, 4.671, 5.1758, 5.7104],
        "y": [0.000084852, 1.8489, 3.6857, 5.6102, 8.2668, 12.907, 18.163, 22.516, 23.525, 24.573, 25.437, 26.851, 28.331, 29.033, 28.95, 29.05, 28.786, 29.12, 29.68, 30.034, 30.521, 31.313, 32.815, 35.117, 37.643, 40.835, 41.976, 43.615],
        "color": "tab:blue",
        "label": "Dataset 1"
    },
    {
        "x": [5.91E-09, 3.22E-04, 0.0012057, 0.0048727, 0.012901, 0.020977, 0.036237, 0.057813, 0.083198, 0.11619, 0.15712, 0.20821, 0.2687, 0.34131, 0.4372, 0.54625, 0.67341, 0.83854, 1.0229, 1.2363, 1.5164, 1.8268, 2.1784, 2.6153, 3.095, 3.6014, 4.0767, 4.5846],
        "y": [0.000088286, 1.8905, 3.7198, 5.3518, 7.4713, 10.569, 14.162, 17.261, 17.666, 18.072, 18.641, 19.904, 21.159, 22.088, 21.873, 21.684, 21.551, 22.015, 22.519, 22.939, 22.946, 22.98, 23.332, 24.252, 25.134, 26.774, 26.809, 27.065],
        "color": "tab:orange",
        "label": "Dataset 2"
    },
    {
        "x": [5.73E-09, 2.86E-04, 9.98E-04, 0.0039314, 0.011148, 0.016971, 0.030044, 0.049411, 0.070838, 0.099856, 0.13608, 0.1792, 0.23079, 0.29309, 0.37503, 0.4683, 0.57688, 0.7166, 0.8722, 1.0522, 1.2894, 1.5509, 1.8484, 2.2262, 2.6393, 3.0822, 3.5345, 4.0185],
        "y": [0.000082648, 1.6834, 3.3004, 4.5538, 6.1721, 8.0943, 10.415, 12.699, 12.864, 12.975, 13.494, 14.404, 15.257, 16.13, 15.958, 15.754, 15.718, 16.096, 16.444, 16.758, 16.516, 16.185, 16.047, 16.309, 16.371, 17.274, 16.537, 15.689],
        "color": "tab:green",
        "label": "Dataset 3"
    }
]

# 그래프 생성
fig, ax = plt.subplots(figsize=(8, 6), facecolor='white')

for dataset in data:
    ax.plot(dataset["x"], dataset["y"], linestyle='-', color=dataset["color"], linewidth=3, label=dataset["label"])
    ax.scatter(dataset["x"][-1], dataset["y"][-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)

# 축 설정
ax.set_xlim(-0.1, 6)
ax.set_ylim(0, 45)
ax.tick_params(axis='x', direction='out', length=6, width=2, labelsize=18)
ax.tick_params(axis='y', direction='out', length=6, width=2, labelsize=18)

# 범례 추가
#ax.legend()

# 굵은 Figure 경계
bold_figure_edge()

# 그래프 출력
plt.tight_layout()
plt.savefig("combined_graph.png", transparent=True)
plt.show()

# %%
y1 = [0.000017392, 0.74164, 1.009, 1.1781, 1.3078, 1.4203, 1.515, 1.5959, 1.6748, 1.7349, 1.8072, 1.8608, 1.917, 1.9688, 2.0161, 2.0592, 2.0922, 2.1265, 2.165, 2.1911, 2.2073, 2.2365, 2.2532, 2.2764, 2.2941, 2.3059, 2.2502, 2.1959, 2.1407, 2.1059, 2.0717]
y2 = [0.000053065, 1.1157, 2.6661, 3.6088, 4.1622, 4.5797, 4.9215, 5.212, 5.4658, 5.666, 5.8728, 6.0472, 6.2086, 6.3291, 6.4411, 6.5468, 6.6395, 6.7175, 6.7858, 6.84, 6.8764, 6.9228, 6.9697, 7.0252, 7.0889, 7.1336, 6.9778, 6.8555, 6.7544, 6.675, 6.6064]
y3 = [0.00010018, 1.7808, 3.7551, 5.9657, 7.8699, 9.1822, 10.278, 11.158, 11.942, 12.543, 13.018, 13.374, 13.653, 13.823, 13.945, 14.041, 14.108, 14.135, 14.129, 14.103, 14.069, 14.086, 14.173, 14.361, 14.709, 15.143, 15.3, 15.308, 15.303, 15.254, 15.13]
y4 = [0.00013571, 2.4, 4.9095, 7.6088, 10.386, 12.974, 15.122, 16.997, 18.458, 19.664, 20.548, 21.145, 21.464, 21.53, 21.42, 21.147, 20.857, 20.589, 20.346, 20.184, 20.28, 20.673, 21.436, 22.319, 23.068, 23.391]
y5 = [0.00010105, 2.1299, 4.3314, 6.6512, 9.1833, 12.026, 14.821, 17.471, 19.971, 21.974, 23.225, 24.457, 25.096, 25.329, 25.374, 25.095, 24.627, 24.016, 23.59, 23.489, 23.861, 24.901, 26.726, 29.018, 30.89, 31.601]
y6 = [0.00010314, 2.0849, 4.2299, 6.5535, 9.287, 12.563, 16.378, 20.416, 24.344, 27.531, 29.619, 31.126, 31.556, 31.357, 30.802, 30.262, 30.214, 30.772, 32.684, 36.632, 42.792, 50.857, 58.315, 63.522, 64.875, 64.391]
y7 = [0.000095397, 1.857, 3.7716, 6.0692, 9.0635, 12.858, 17.694, 22.691, 27.59, 31.235, 34.145, 36.017, 36.74, 37.133, 37.126, 38.206, 43.127, 53.452, 70.375, 89.787, 102.48, 106.61, 103.54, 97.438, 89.818, 81.983]

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# 새로운 데이터
x1_new = [
    0, 0.0035, 0.00865, 0.0144, 0.0206, 0.0272, 0.03405, 0.04115, 0.04855, 
    0.05625, 0.06425, 0.07255, 0.08105, 0.08985, 0.099, 0.10845, 0.1183, 
    0.12865, 0.1394, 0.1506, 0.16245, 0.1749, 0.18805, 0.20195, 0.2166, 0.2319
]
y1_new = [0.000017392, 0.74164, 1.009, 1.1781, 1.3078, 1.4203, 1.515, 1.5959, 1.6748, 1.7349, 1.8072, 1.8608, 1.917, 1.9688, 2.0161, 2.0592, 2.0922, 2.1265, 2.165, 2.1911, 2.2073, 2.2365, 2.2532, 2.2764, 2.2941, 2.3059]

x2_new = [
    0, 0.0051, 0.01885, 0.03575, 0.05385, 0.0728, 0.09245, 0.113, 0.1343, 
    0.15635, 0.1792, 0.2032, 0.2283, 0.2542, 0.28135, 0.3098, 0.33975, 
    0.3714, 0.40485, 0.4404, 0.4782, 0.51865, 0.562, 0.6086, 0.6586, 
    0.712, 0.7645, 0.8155, 0.8641, 0.9093, 0.9498
]
y2_new = [0.000053065, 1.1157, 2.6661, 3.6088, 4.1622, 4.5797, 4.9215, 5.212, 5.4658, 5.666, 5.8728, 6.0472, 6.2086, 6.3291, 6.4411, 6.5468, 6.6395, 6.7175, 6.7858, 6.84, 6.8764, 6.9228, 6.9697, 7.0252, 7.0889, 7.1336, 6.9778, 6.8555, 6.7544, 6.675, 6.6064]

x3_new = [
    0, 0.00515, 0.02015, 0.04515, 0.0766, 0.11085, 0.1471, 0.18505, 0.22465, 
    0.2662, 0.30945, 0.35465, 0.4026, 0.45285, 0.5059, 0.5625, 0.623, 
    0.68765, 0.75725, 0.8324, 0.91395, 1.00285, 1.1002, 1.207, 1.32405, 
    1.44995, 1.57655, 1.69875, 1.81515, 1.924, 2.024
]
y3_new = [0.00010018, 1.7808, 3.7551, 5.9657, 7.8699, 9.1822, 10.278, 11.158, 11.942, 12.543, 13.018, 13.374, 13.653, 13.823, 13.945, 14.041, 14.108, 14.135, 14.129, 14.103, 14.069, 14.086, 14.173, 14.361, 14.709, 15.143, 15.3, 15.308, 15.303, 15.254, 15.13]

# 기존 데이터 (3, 10, 20 um)
x1 = [
    0, 0.00625, 0.02405, 0.0541, 0.095, 0.1434, 0.196, 0.25205, 0.3117, 
    0.37525, 0.44205, 0.51295, 0.58915, 0.67105, 0.76, 0.8574, 0.9651, 
    1.0852, 1.2203, 1.37355, 1.54875, 1.74945, 1.97735, 2.2294, 2.49755, 2.7732
]
y1 = [0.00013571, 2.4, 4.9095, 7.6088, 10.386, 12.974, 15.122, 16.997, 18.458, 19.664, 20.548, 21.145, 21.464, 21.53, 21.42, 21.147, 20.857, 20.589, 20.346, 20.184, 20.28, 20.673, 21.436, 22.319, 23.068, 23.391]

x2 = [
    0, 0.005775, 0.02185, 0.04865, 0.08595, 0.1321, 0.185375, 0.24395, 0.307,
    0.37395, 0.445275, 0.52085, 0.601575, 0.688675, 0.784075, 0.88835,
    1.004575, 1.13525, 1.283975, 1.454925, 1.65325, 1.88425, 2.153, 2.4595,
    2.79575, 3.14075
]
y2 = [0.00010105, 2.1299, 4.3314, 6.6512, 9.1833, 12.026, 14.821, 17.471, 19.971, 21.974, 23.225, 24.457, 25.096, 25.329, 25.374, 25.095, 24.627, 24.016, 23.59, 23.489, 23.861, 24.901, 26.726, 29.018, 30.89, 31.601]

x3 = [
    0, 0.00626, 0.024, 0.05344, 0.0941, 0.14452, 0.2033, 0.2692, 0.34112,
    0.41866, 0.50234, 0.59332, 0.69318, 0.80448, 0.93062, 1.0762, 1.2476,
    1.4546, 1.7092, 2.027, 2.42, 2.8734, 3.3232, 3.6974, 3.9694, 4.1644
]
y3 = [0.000095397, 1.857, 3.7716, 6.0692, 9.0635, 12.858, 17.694, 22.691, 27.59, 31.235, 34.145, 36.017, 36.74, 37.133, 37.126, 38.206, 43.127, 53.452, 70.375, 89.787, 102.48, 106.61, 103.54, 97.438, 89.818, 81.983]


###############################################################################
# 1) Figure, Axes 생성 시 facecolor='white' (투명은 facecolor='none')
###############################################################################
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)

# 모든 선 굵기 통일: linewidth=3
# (1) 기존 데이터 3, 10, 20 um
ax.plot(x1, y1, linestyle='-', color='tab:blue', linewidth=3, label="3 um (old)")
ax.scatter(x1[-1], y1[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)

ax.plot(x2, y2, linestyle='-', color='tab:orange', linewidth=3, label="10 um (old)")
ax.scatter(x2[-1], y2[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)

ax.plot(x3, y3, linestyle='-', color='tab:green', linewidth=3, label="20 um (old)")
ax.scatter(x3[-1], y3[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)

# (2) 새 데이터 0.1, 0.5, 1.5 um
ax.plot(x1_new, y1_new, linestyle='-', color='tab:red', linewidth=3, label="1.5 um (new)")
ax.plot(x2_new, y2_new, linestyle='-', color='tab:purple', linewidth=3, label="0.5 um (new)")
ax.plot(x3_new, y3_new, linestyle='-', color='tab:brown', linewidth=3, label="0.1 um (new)")

ax.scatter(x1_new[-1], y1_new[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)
ax.scatter(x2_new[-1], y2_new[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)
ax.scatter(x3_new[-1], y3_new[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)

# 축 눈금 설정 (크기는 tick_params의 labelsize 인자로 조절)
# labelbottom=True, labelleft=True로 해서 숫자가 보이게 설정
ax.tick_params(
    axis='x', direction='out', length=6, width=2, 
    labelbottom=True, labelsize=18  # <-- 여기서 숫자 크기 조절
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2, 
    labelleft=True, labelsize=18    # <-- 여기서 숫자 크기 조절
)

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 축 범위 조정 (필요시 수정)
ax.set_xlim(min(x1) - 0.1*min(x1), max(x3) + max(x3)*0.1)
ax.set_ylim(min(y1) - 0.01, 50)

# 파괴 기준선 (점선)만 표시
threshold = 45
ax.axhline(threshold, color='black', linestyle='--', linewidth=2, zorder=2)

# 20 um에서 threshold 초과 구간 표시 (예시)
exceed_indices = [i for i, val in enumerate(y3) if val >= threshold]
if exceed_indices:
    idx_fail_start = exceed_indices[0]
    x_fail = x3[idx_fail_start]
    y_fail = y3[idx_fail_start]
    ax.annotate(
        "Failure",
        xy=(x_fail, y_fail),
        xytext=(x_fail+0.2, y_fail+5),
        arrowprops=dict(
            arrowstyle="->",
            color='red'
        ),
        fontsize=12,
        color='red'
    )

plt.savefig("particle_size_SS_curve_firstPiola.png", transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt

# 사용자 정의 rc 설정
rc = plt.rc
rc('lines', lw=2)
rc('font', size=16)
rc('xtick', labelsize=18)
rc('xtick.major', size=5, width=3)
rc('ytick.major', size=5, width=3)
rc('legend', fontsize=15, frameon=False, loc='best')

### 굵은 Figure 경계 ###
def bold_figure_edge():
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        for ax in figure.canvas.figure.get_axes():
            ax.spines['top'].set_linewidth(3)
            ax.spines['bottom'].set_linewidth(3)
            ax.spines['left'].set_linewidth(3)
            ax.spines['right'].set_linewidth(3)

# ------------------------------------------------------------------------------
# [새 데이터 (예: 0.1 um, 0.5 um, 1.5 um)]
# ------------------------------------------------------------------------------
x1_new = [
    0, 0.0035, 0.00865, 0.0144, 0.0206, 0.0272, 0.03405, 0.04115, 0.04855, 
    0.05625, 0.06425, 0.07255, 0.08105, 0.08985, 0.099, 0.10845, 0.1183, 
    0.12865, 0.1394, 0.1506, 0.16245, 0.1749, 0.18805, 0.20195, 0.2166, 0.2319
]
y1_new = [0.000017392, 0.74164, 1.009, 1.1781, 1.3078, 1.4203, 1.515, 1.5959, 1.6748, 1.7349, 1.8072, 1.8608, 1.917, 1.9688, 2.0161, 2.0592, 2.0922, 2.1265, 2.165, 2.1911, 2.2073, 2.2365, 2.2532, 2.2764, 2.2941, 2.3059]

x2_new = [
    0, 0.0051, 0.01885, 0.03575, 0.05385, 0.0728, 0.09245, 0.113, 0.1343, 
    0.15635, 0.1792, 0.2032, 0.2283, 0.2542, 0.28135, 0.3098, 0.33975, 
    0.3714, 0.40485, 0.4404, 0.4782, 0.51865, 0.562, 0.6086, 0.6586, 
    0.712, 0.7645, 0.8155, 0.8641, 0.9093, 0.9498
]
y2_new = [0.000053065, 1.1157, 2.6661, 3.6088, 4.1622, 4.5797, 4.9215, 5.212, 5.4658, 5.666, 5.8728, 6.0472, 6.2086, 6.3291, 6.4411, 6.5468, 6.6395, 6.7175, 6.7858, 6.84, 6.8764, 6.9228, 6.9697, 7.0252, 7.0889, 7.1336, 6.9778, 6.8555, 6.7544, 6.675, 6.6064]



###############################################################################
# 1) Figure, Axes 생성 시 facecolor='white' (투명은 facecolor='none')
###############################################################################
fig = plt.figure(figsize=(8,6), facecolor='white')
ax = fig.add_subplot(111)


# (2) 새 데이터 0.1, 0.5, 1.5 um
ax.plot(x1_new, y1_new, linestyle='-', color='tab:red', linewidth=3, label="0.1 um")
ax.plot(x2_new, y2_new, linestyle='-', color='tab:purple', linewidth=3, label="0.5 um")


ax.scatter(x1_new[-1], y1_new[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)
ax.scatter(x2_new[-1], y2_new[-1], color='red', zorder=5, s=80, edgecolors='black', linewidth=1)


# 축 눈금 설정 (크기는 tick_params의 labelsize 인자로 조절)
# labelbottom=True, labelleft=True로 해서 숫자가 보이게 설정
ax.tick_params(
    axis='x', direction='out', length=6, width=2, 
    labelbottom=True, labelsize=18  # 숫자 크기
)
ax.tick_params(
    axis='y', direction='out', length=6, width=2, 
    labelleft=True, labelsize=18    # 숫자 크기
)

# 라벨, 제목 제거
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_title("")

# 격자 제거
ax.grid(False)

# 굵은 Figure 경계
bold_figure_edge()

# 축 범위 조정 (필요시 수정)
ax.set_xlim(min(x1) - 0.1*min(x1), 2)
ax.set_ylim(min(y1) - 0.01, 12)

# 투명 배경으로 저장하고 싶다면 transparent=True 지정
plt.savefig("particle_size_smallsize_SS_curve_firstpiola.png", transparent=True)
plt.show()
